# %% [markdown]
# # Asynchronous One Step Deep Q-Network (DQN)
#
# ### 0.Background: introduce Asynchronous to DQN
#
# Traditional [Deep Q-Networks (DQN)](../vanilla-dqn/dqn_lunarlander.ipynb) have been highly successful in solving reinforcement learning tasks by combining Q-learning with deep neural networks. However, they often require significant computational resources and suffer from stability issues during training. To address these challenges, **Asynchronous DQN** introduces the concept of **asynchronous multi-threading**, where multiple agents (or threads) interact with their own copies of the environment in parallel. This approach provides several benefits:
#
# 1. **Improved computational efficiency**:
#    - By leveraging multiple threads, the algorithm can make better use of multi-core CPUs, enabling faster training without requiring expensive GPUs.
#
# 2. **Stabilized training**:
#    - Asynchronous updates reduce the correlation between consecutive updates, which helps mitigate the instability caused by highly correlated training data in traditional DQN.
#
# 3. **Enhanced exploration**:
#    - By assigning different exploration policies to each thread, Asynchronous DQN encourages diverse exploration, leading to better coverage of the state-action space.

# %% [markdown]
# ### 1. Import the Necessary Packages
#
# In this notebook, we will implement a DQN agent with OpenAI Gym's LunarLander-v2 environment.

# %%
import numpy as np
import gymnasium as gym
from collections import deque

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random

# for game rendering
import time
from PIL import Image
from IPython import display

device = torch.device("cpu")
print(f"Training on: {device}")

np.set_printoptions(precision=3, linewidth=120)
# Out:
# Training on: cpu

# %% [markdown]
# ### 2. Explore Environment
#
# <div style="text-align: center;">
#     <img src="./images/lunar_lander.gif" alt="Mountain Car Environment" width="50%">
# </div>
#
# #### Discreate Action Space
#
# There are four discrete actions available:
#
# - 0: do nothing
# - 1: fire left orientation engine
# - 2: fire main engine
# - 3: fire right orientation engine
#
# #### Continuous Observation Space
#
# The state is an 8-dimensional vector:
#
# - the coordinates of the lander in `x`
# - the coordinates of the lander in`y`,
# - linear velocities in `x`
# - linear velocities in `y`,
# - its angle,
# - its angular velocity, and
# - a booleans that represent whether `left` leg is in contact with the ground or not.
# - a booleans that represent whether `right` leg is in contact with the ground or not.

# %%
env = gym.make('LunarLander-v3', render_mode="rgb_array")

# %%
# Explore state (observation) space
print("State space:\n Continuous", env.observation_space.shape)
print(" - low:", env.observation_space.low)
print(" - high:", env.observation_space.high)

# Explore action space
print("Action space:\n", env.action_space)

print("-"*50)
# Generate some samples from the state space 
print("State space 10 samples:")
print(np.array([env.observation_space.sample() for i in range(10)]))

# Generate some samples from the action space
print("Action space 10 samples:")
print(np.array([env.action_space.sample() for i in range(10)]))
# Out:
# State space:
#  Continuous (8,)
#  - low: [ -2.5    -2.5   -10.    -10.     -6.283 -10.     -0.     -0.   ]
#  - high: [ 2.5    2.5   10.    10.     6.283 10.     1.     1.   ]
# Action space:
#  Discrete(4)
# --------------------------------------------------
# State space 10 samples:
# [[-1.672  1.372 -2.095 -6.086 -5.166 -5.27   0.695  0.296]
#  [ 1.992 -0.661 -1.177 -7.604  5.288  8.819  0.297  0.361]
#  [-0.732 -1.347 -0.675 -1.23  -2.339  7.345  0.199  0.341]
#  [-1.572  1.812  7.556 -4.559  1.222 -4.305  0.346  0.1  ]
#  [-1.231  0.994 -0.786 -0.339  4.925 -1.335  0.225  0.487]
#  [ 2.081  1.051 -2.106  7.394 -2.226 -0.101  0.853  0.106]
#  [ 2.332  1.49   9.098  5.481  0.42  -2.332  0.654  0.452]
#  [-2.434 -1.231 -7.237 -9.658  0.472 -1.891  0.923  0.076]
#  [-0.486  0.082  9.126  4.984  4.265 -0.401  0.217  0.46 ]
#  [ 1.558  0.608 -2.42   4.515 -4.672 -0.155  0.712  0.597]]
# Action space 10 samples:
# [0 1 3 3 2 1 0 1 3 2]

# %% [markdown]
# ### 3. Remove Replay Buffer
#
# #### Using Experience Replay Improve Training Stability
#
# <div style="text-align: center;">
#     <img src="./images/reply-buffer.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# When an agent interacts with the environment, the sequence of experience tuples can be highly correlated, which poses a risk for naive Q-learning algorithms. These algorithms, when learning sequentially from such correlated data, may lead to unstable updates, causing action values to oscillate or diverge.
#
# To address this, a replay buffer is introduced to store experience tuples $(S, A, R, S')$ collected during interactions with the environment. By using **experience replay**, small batches of tuples are randomly sampled from the buffer for training. This random sampling breaks harmful correlations, stabilizes learning, and allows the agent to:
# 1. Reuse individual experience tuples multiple times.
# 2. Recall rare events.
# 3. Make better overall use of past experiences.
#
# Experience replay thus improves the efficiency and stability of the learning process.
#
# <span style="color: red;">Update: </span> However, asynchronous methods eliminate the need for a replay buffer. In asynchronous one-step Q-learning and related methods, multiple agents (threads) interact with their own copies of the environment in parallel. This naturally introduces diversity into the data collected by each thread, breaking the correlation between consecutive updates. As a result:
#
# The updates from different threads act as a form of implicit decorrelation, reducing the risk of instability.
# The computational complexity of managing a replay buffer is avoided, making the algorithm simpler and more efficient.
# Thus, asynchronous mechanisms provide a built-in alternative to experience replay, achieving stability and efficiency without the need for a replay buffer.

# %% [markdown]
# ### 4. Define Q Network
#
# #### Using Neural Networks as Approximators for Q values
#
# <div style="text-align: center;">
#     <img src="./images/model-view.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# This image shows the transition from a **Traditional Q Table** to a **Parameterized Q Function** in reinforcement learning.
#
# The Q table (left) stores discrete Q-values $ Q(s_t, a_t) $ for each state-action pair but struggles with scalability in high-dimensional spaces. The parameterized Q function (right) replaces the table with a neural network $ Q(s_t, a_t; w) $, where $ w $ are the network's parameters.
#
# <div style="text-align: center;">
#     <img src="./images/model-arch.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# - Define a neural network architecture that maps states to action values $Q(s_t, a_t; w)$.

# %%
class QNetwork(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, hidden_size=64, seed=42):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.Q = nn.Sequential(
            nn.Linear(state_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, action_size)
        )

    def forward(self, state):
        """Build a network that maps state -> action values."""
        actions = self.Q(state)
        return actions


# test model
q_net = QNetwork(8, 4, 16, seed=42)
# fake input, by given batch size 4
states = torch.rand((4, 8))
# fake output size
print(q_net(states).shape)
# Out:
# torch.Size([4, 4])

# %% [markdown]
# ### 5. Define Agent
#
# ##### How to Learn in DQN
#
# <div style="text-align: center;">
#     <img src="./images/dqn-gradient-descent.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# This image provides a visual summary of the core theory and update mechanism of **Deep Q-Network (DQN)**, showcasing the key formula derivations from **Q-Learning** to **DQN**, as well as how neural networks are used to approximate and update Q-values.
#
# ---
#
# **1. Core Idea Based on the Bellman Equation**
# - **Bellman Equation:**
#   $$
#   Q^*(s_t, a_t) = R_t + \gamma \max_a Q^*(s_{t+1}, a)
#   $$
#   - This states that the optimal Q-value for the current state-action pair equals the immediate reward $ R_t $ plus the discounted maximum Q-value of the next state.
#   - The core objective of DQN is to approximate this equation using a neural network.
#
# **2. Derivation from Q-Learning to DQN**
# - **Q-Learning Update Formula:**
#   $$
#   Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \alpha \left( R_t + \gamma \max_a Q(s_{t+1}, a) - Q(s_t, a_t) \right)
#   $$
#   - **TD Target:**
#     $$
#     R_t + \gamma \max_a Q(s_{t+1}, a)
#     $$
#     This represents the target Q-value for the current state, combining the immediate reward $ R_t $ and the maximum Q-value of the next state.
#   - **Current Value:**
#     $$
#     Q(s_t, a_t)
#     $$
#     This is the current estimated Q-value.
#   - **TD Error:**
#     $$
#     \delta_t = \left( R_t + \gamma \max_a Q(s_{t+1}, a) - Q(s_t, a_t) \right)
#     $$
#     This measures the difference between the target Q-value and the current Q-value.
#
# - **Neural Network Introduction:**
#   - To handle continuous state spaces, DQN replaces the traditional Q-table with a neural network $ Q(s, a; w) $, where $ w $ represents the network parameters.
#   - The goal is to optimize the network so that its output $ Q(s, a; w) $ approximates the true $ Q^*(s, a) $.
#
#
# **3. Loss Function and Gradient Update in DQN**
# - **Loss Function:**
#   $$
#   L(w) = \frac{1}{2} \left[ Q(s_t, a_t; w) - Q^*(s_t, a_t) \right]^2
#   $$
#   - Here, $ Q^*(s_t, a_t) $ is the target Q-value (TD Target) calculated using the Bellman equation.
#   - The loss function minimizes the squared error between the network's output $ Q(s_t, a_t; w) $ and the target Q-value $ Q^*(s_t, a_t) $.
#
# - **Gradient Calculation:**
#   $$
#   \nabla_w L(w) = \left( Q(s_t, a_t; w) - Q^*(s_t, a_t) \right) \nabla_w Q(s_t, a_t; w)
#   $$
#   - The gradient consists of two parts:
#     1. The error term: $ Q(s_t, a_t; w) - Q^*(s_t, a_t) $
#     2. The gradient of the network output: $ \nabla_w Q(s_t, a_t; w) $
#
# - **Weight Update:**
#   $$
#   w \leftarrow w - \alpha \nabla_w L(w)
#   $$
#   - Using gradient descent, the network parameters $ w $ are updated to reduce the loss function.
#
# - **Final DQN Update Formula:**
#   $$
#   L(w) = \frac{1}{2} \left[ Q(s_t, a_t; w) - (R_t + \gamma \max_a Q(s_{t+1}, a; w^-)) \right]^2
#   $$
#
#   $$
#   w' \leftarrow w + \alpha \left( R_t + \gamma \max_a Q(s_{t+1}, a; w^-) - Q(s_t, a_t; w) \right) \nabla_w Q(s_t, a_t; w)
#   $$
#   - Here, $ w^- $ represents the fixed target network parameters during the learning step, which are used to stabilize training.
#
#
# <span style="color: red;">Update: </span> **Asynchronous Version**
#
# Like Paper [Asynchronous Methods for Deep Reinforcement Learning](https://arxiv.org/pdf/1602.01783) illustrated, we can implement Asynchronous DQN like below with few modifications:
#
# <div style="text-align: center;">
#     <img src="./images/async-dqn-psedocode.png" width="40%">
# </div>

# %%
class Agent:
    """Interacts with and learns from the environment."""

    def __init__(
        self,
        state_size,
        action_size,
        Q_network,
        Q_target_network=None,
        optimizer=None,
        gamma=0.99,
        target_update_steps=1000,
        update_steps=5,
        seed=42,
        T=None,
        optimizer_lock=None
    ):
        """
        Initialize the agent.
        Args:
            state_size (int): Dimension of the state space.
            action_size (int): Dimension of the action space.
            Q_network (QNetwork): Main Q-Network.
            Q_target_network (QNetwork): Target Q-Network.
            optimizer (torch.optim.Optimizer): Optimizer for training.
            gamma (float): Discount factor.
            target_update_steps (int): Steps between target network updates.
            update_steps (int): Steps between gradient application.
            seed (int): Random seed for reproducibility.
            T (multiprocessing.Value): Global step counter shared across processes.
            optimizer_lock (multiprocessing.Lock): Lock for synchronizing optimizer updates.
        """
        self.state_size = state_size
        self.action_size = action_size
        self.Q = Q_network
        self.Q_target = Q_target_network
        self.optimizer = optimizer
        self.gamma = gamma
        self.target_update_steps = target_update_steps
        self.update_steps = update_steps  # Number of steps after which to apply gradients
        self.t_step = 0  # Time step counter for this thread
        self.T = T  # Shared global counter
        self.optimizer_lock = optimizer_lock
        self.seed = np.random.seed(seed)
        random.seed(seed)

        # Initialize accumulated gradients as None
        self.reset_gradients()
    
    def reset_gradients(self):
        """Reset accumulated gradients."""
        self.accumulated_grads = [torch.zeros_like(p) for p in self.Q.parameters()]
    
    def select_action(self, state, epsilon=0.0):
        """Selects an action using epsilon-greedy policy."""
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.Q.eval()
        with torch.no_grad():
            actions = self.Q(state)
        self.Q.train()

        # Epsilon-greedy action selection
        if random.random() > epsilon:
            return np.argmax(actions.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def step(self, state, action, reward, next_state, done):
        """Processes a step and learns from the experience."""
        # Convert experience to tensors
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        action = torch.tensor([[action]], dtype=torch.int64).to(device)
        reward = torch.tensor([[reward]], dtype=torch.float32).to(device)
        next_state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)
        done = torch.tensor([[done]], dtype=torch.float32).to(device)

        # Perform learning step
        loss = self.compute_loss((state, action, reward, next_state, done))
        
        # Backpropagate loss and accumulate gradients
        self.Q.zero_grad()
        loss.backward()

        # Accumulate gradients
        with torch.no_grad():
            for acc_grad, param in zip(self.accumulated_grads, self.Q.parameters()):
                acc_grad += param.grad.clone()

        # Increment step counters
        self.t_step += 1
        with self.T.get_lock():
            self.T.value += 1

        # Check if it's time to apply accumulated gradients
        if self.t_step % self.update_steps == 0 or done.item():
            self.apply_gradients()
            self.reset_gradients()
        
        # Update target network
        if self.T.value % self.target_update_steps == 0:
            self.hard_update()
        
    def compute_loss(self, experience):
        """Computes the loss for a single experience tuple."""
        state, action, reward, next_state, done = experience

        # Compute TD target using the target network
        with torch.no_grad():
            Q_targets_next = torch.max(self.Q_target(next_state), dim=-1, keepdim=True)[0]
            Q_targets = reward + (1 - done) * self.gamma * Q_targets_next

        # Compute expected Q values using the local network
        Q_expected = torch.gather(self.Q(state), dim=-1, index=action)

        # Compute loss (mean squared error)
        loss = F.mse_loss(Q_expected, Q_targets)
        return loss

    def apply_gradients(self):
        """Apply accumulated gradients to the shared network."""
        with self.optimizer_lock:
            for param, acc_grad in zip(self.Q.parameters(), self.accumulated_grads):
                param.grad = acc_grad  # Set the accumulated gradients

            # Perform optimizer step
            self.optimizer.step()
            # Zero the parameter gradients (in case they weren't zeroed)
            self.optimizer.zero_grad()
 
    def hard_update(self):
        """Hard update: θ_target = θ"""
        with self.optimizer_lock:
            self.Q_target.load_state_dict(self.Q.state_dict())

# %% [markdown]
# ### 7. Train the Agent with Async DQN

# %%
class SharedAdam(optim.Adam):
    """Shared Adam optimizer for multiprocessing"""

    def __init__(self, params, lr=5e-4):
        """
        Initialize the shared Adam optimizer.
        Args:
            params: Parameters to optimize.
            lr (float): Learning rate.
        """
        super(SharedAdam, self).__init__(params, lr=lr)
        for group in self.param_groups:
            for p in group['params']:
                # Initialize optimizer state
                state = self.state[p]
                state['step'] = torch.tensor(0)
                state['exp_avg'] = torch.zeros_like(p.data)
                state['exp_avg_sq'] = torch.zeros_like(p.data)
                # Share memory for multiprocessing
                state['exp_avg'].share_memory_()
                state['exp_avg_sq'].share_memory_()
                state['step'].share_memory_()

# %%
def worker_dqn(rank, Q, Q_target, optimizer, T, max_score, env_name, num_episodes=2000, max_t=1000, window=100, optimizer_lock=None):
    """
    Function executed by each worker process.
    Args:
        rank (int): Process rank.
        Q (QNetwork): Shared Q-network.
        Q_target (QNetwork): Shared target Q-network.
        optimizer (SharedAdam): Shared optimizer.
        T (multiprocessing.Value): Global step counter.
        max_score (multiprocessing.Value): Global maximum score.
        env_name (str): Environment name.
        num_episodes (int): Number of training episodes.
        max_t (int): Maximum steps per episode.
        window (int): Window size for calculating average scores.
        optimizer_lock (multiprocessing.Lock): Lock for synchronizing optimizer updates.
    """
    # Create an environment instance for each worker
    env = gym.make(env_name)
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # Initialize the agent with shared networks and optimizer
    agent = Agent(
        state_size=state_size,
        action_size=action_size,
        Q_network=Q,
        Q_target_network=Q_target,
        optimizer=optimizer,
        gamma=0.995,
        target_update_steps=50,
        update_steps=10,
        seed=42 + rank,
        T=T,
        optimizer_lock=optimizer_lock
    )
    
    epsilon = 1.0
    eps_min = 0.01
    eps_decay = 0.999
    
    scores_window = deque(maxlen=window)

    for i_episode in range(1, num_episodes + 1):
        with max_score.get_lock():
            if max_score.value >= 200.0:
                break
            
        state, _ = env.reset()
        total_reward = 0
        agent.t_step = 0
        agent.reset_gradients()
        done = False

        for t in range(max_t):
            action = agent.select_action(state, epsilon)
            next_state, reward, done, _, info = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            if done:
                break
        
        # Decay epsilon
        epsilon = max(eps_min, eps_decay * epsilon)
        
        scores_window.append(total_reward)
        mean_score = np.mean(scores_window)

        if i_episode % 10 == 0:
            print(f"Process {rank}, Episode {i_episode}, Total Reward: {total_reward:.2f}, Average Score: {mean_score:.2f}")

        if len(scores_window) >= window and mean_score >= 200.0:
            with max_score.get_lock():
                max_score.value = mean_score
                if rank == 0:
                    print(f"\nEnvironment solved in {i_episode:d} episodes!\tAverage Score: {mean_score:.2f}")
                    torch.save(agent.Q.state_dict(), "checkpoint.pth")
            break

    env.close()

# %% [markdown]
# <span style="color: red;">Update: </span> Below code in this [script](./asynchronous_dqn_lunarlander.py)

# %%
# %run asynchronous_dqn_lunarlander.py
# Out:
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Process 6, Episode 10, Total Reward: -262.12, Average Score: -198.45
# Process 1, Episode 10, Total Reward: -183.37, Average Score: -192.77
# Process 2, Episode 10, Total Reward: -163.37, Average Score: -149.55
# Process 0, Episode 10, Total Reward: -438.55, Average Score: -214.16
# Process 4, Episode 10, Total Reward: -92.51, Average Score: -175.21
# Process 7, Episode 10, Total Reward: -278.75, Average Score: -195.67
# Process 3, Episode 10, Total Reward: -172.37, Average Score: -216.38
# Process 5, Episode 10, Total Reward: -184.42, Average Score: -161.08
# Process 6, Episode 20, Total Reward: -113.52, Average Score: -177.86
# Process 1, Episode 20, Total Reward: -406.74, Average Score: -197.91
# Process 2, Episode 20, Total Reward: -377.29, Average Score: -189.46
# Process 4, Episode 20, Total Reward: -175.50, Average Score: -174.97
# Process 0, Episode 20, Total Reward: -359.48, Average Score: -213.01
# Process 5, Episode 20, Total Reward: -94.66, Average Score: -172.73
# Process 3, Episode 20, Total Reward: -115.55, Average Score: -203.36
# Process 7, Episode 20, Total Reward: -147.51, Average Score: -166.22
# Process 6, Episode 30, Total Reward: -121.70, Average Score: -178.08
# Process 5, Episode 30, Total Reward: -181.00, Average Score: -173.31
# Process 4, Episode 30, Total Reward: -107.66, Average Score: -175.68
# Process 2, Episode 30, Total Reward: -224.31, Average Score: -185.83
# Process 0, Episode 30, Total Reward: -121.52, Average Score: -200.25
# Process 1, Episode 30, Total Reward: -109.59, Average Score: -196.75
# Process 3, Episode 30, Total Reward: -297.32, Average Score: -200.73
# Process 7, Episode 30, Total Reward: -105.19, Average Score: -163.86
# Process 6, Episode 40, Total Reward: -151.21, Average Score: -164.37
# Process 1, Episode 40, Total Reward: -121.17, Average Score: -184.77
# Process 4, Episode 40, Total Reward: -342.67, Average Score: -178.46
# Process 5, Episode 40, Total Reward: -222.21, Average Score: -170.31
# Process 0, Episode 40, Total Reward: -211.05, Average Score: -193.83
# Process 2, Episode 40, Total Reward: -228.44, Average Score: -182.88
# Process 3, Episode 40, Total Reward: -87.04, Average Score: -184.81
# Process 7, Episode 40, Total Reward: -73.01, Average Score: -156.27
# Process 6, Episode 50, Total Reward: -290.34, Average Score: -167.05
# Process 1, Episode 50, Total Reward: -95.22, Average Score: -177.92
# Process 0, Episode 50, Total Reward: -130.80, Average Score: -187.22
# Process 4, Episode 50, Total Reward: -126.40, Average Score: -179.44
# Process 5, Episode 50, Total Reward: -196.62, Average Score: -170.49
# Process 3, Episode 50, Total Reward: -117.82, Average Score: -182.60
# Process 2, Episode 50, Total Reward: -73.81, Average Score: -179.87
# Process 7, Episode 50, Total Reward: -75.37, Average Score: -159.72
# Process 6, Episode 60, Total Reward: -223.98, Average Score: -161.54
# Process 1, Episode 60, Total Reward: -54.26, Average Score: -174.19
# Process 5, Episode 60, Total Reward: -112.82, Average Score: -173.00
# Process 0, Episode 60, Total Reward: -79.25, Average Score: -188.67
# Process 4, Episode 60, Total Reward: -281.24, Average Score: -182.48
# Process 2, Episode 60, Total Reward: -123.51, Average Score: -175.33
# Process 3, Episode 60, Total Reward: -104.80, Average Score: -176.37
# Process 7, Episode 60, Total Reward: -140.10, Average Score: -158.10
# Process 6, Episode 70, Total Reward: -151.64, Average Score: -166.28
# Process 1, Episode 70, Total Reward: -70.39, Average Score: -171.78
# Process 4, Episode 70, Total Reward: -99.97, Average Score: -172.88
# Process 0, Episode 70, Total Reward: -105.53, Average Score: -181.57
# Process 5, Episode 70, Total Reward: -140.11, Average Score: -176.00
# Process 2, Episode 70, Total Reward: -146.87, Average Score: -174.17
# Process 3, Episode 70, Total Reward: -235.82, Average Score: -173.15
# Process 7, Episode 70, Total Reward: -53.82, Average Score: -154.78
# Process 1, Episode 80, Total Reward: -180.49, Average Score: -172.30
# Process 6, Episode 80, Total Reward: -109.64, Average Score: -167.96
# Process 4, Episode 80, Total Reward: -208.74, Average Score: -170.28
# Process 2, Episode 80, Total Reward: -83.07, Average Score: -169.60
# Process 0, Episode 80, Total Reward: -98.00, Average Score: -182.20
# Process 5, Episode 80, Total Reward: -70.74, Average Score: -168.90
# Process 3, Episode 80, Total Reward: -153.12, Average Score: -170.02
# Process 7, Episode 80, Total Reward: -70.59, Average Score: -154.36
# Process 1, Episode 90, Total Reward: -109.57, Average Score: -164.82
# Process 4, Episode 90, Total Reward: -106.58, Average Score: -166.07
# Process 6, Episode 90, Total Reward: -129.61, Average Score: -166.18
# Process 2, Episode 90, Total Reward: -144.01, Average Score: -165.59
# Process 3, Episode 90, Total Reward: -88.65, Average Score: -163.17
# Process 0, Episode 90, Total Reward: -275.70, Average Score: -178.14
# Process 5, Episode 90, Total Reward: -87.31, Average Score: -164.56
# Process 7, Episode 90, Total Reward: -108.32, Average Score: -158.12
# Process 4, Episode 100, Total Reward: -83.66, Average Score: -162.15
# Process 2, Episode 100, Total Reward: -175.43, Average Score: -163.31
# Process 3, Episode 100, Total Reward: -145.56, Average Score: -164.85
# Process 0, Episode 100, Total Reward: -64.29, Average Score: -171.13
# Process 5, Episode 100, Total Reward: -148.26, Average Score: -162.37
# Process 1, Episode 100, Total Reward: -137.19, Average Score: -157.77
# Process 7, Episode 100, Total Reward: -159.55, Average Score: -161.75
# Process 6, Episode 100, Total Reward: -253.30, Average Score: -163.84
# Process 4, Episode 110, Total Reward: -161.11, Average Score: -158.75
# Process 2, Episode 110, Total Reward: -92.30, Average Score: -162.27
# Process 0, Episode 110, Total Reward: -413.09, Average Score: -169.01
# Process 3, Episode 110, Total Reward: -226.86, Average Score: -161.66
# Process 5, Episode 110, Total Reward: -112.88, Average Score: -160.26
# Process 1, Episode 110, Total Reward: -131.34, Average Score: -153.48
# Process 7, Episode 110, Total Reward: -192.10, Average Score: -153.52
# Process 6, Episode 110, Total Reward: -154.50, Average Score: -154.02
# Process 4, Episode 120, Total Reward: -98.62, Average Score: -155.45
# Process 2, Episode 120, Total Reward: -56.60, Average Score: -154.55
# Process 0, Episode 120, Total Reward: -181.87, Average Score: -163.73
# Process 3, Episode 120, Total Reward: -100.38, Average Score: -152.75
# Process 5, Episode 120, Total Reward: -54.34, Average Score: -154.84
# Process 7, Episode 120, Total Reward: -378.54, Average Score: -159.01
# Process 1, Episode 120, Total Reward: -171.60, Average Score: -149.38
# Process 6, Episode 120, Total Reward: -102.96, Average Score: -150.70
# Process 0, Episode 130, Total Reward: -25.66, Average Score: -159.92
# Process 4, Episode 130, Total Reward: -183.09, Average Score: -153.50
# Process 3, Episode 130, Total Reward: -104.39, Average Score: -148.24
# Process 2, Episode 130, Total Reward: -86.27, Average Score: -149.24
# Process 5, Episode 130, Total Reward: -73.46, Average Score: -154.30
# Process 7, Episode 130, Total Reward: -76.51, Average Score: -154.48
# Process 6, Episode 130, Total Reward: -158.27, Average Score: -140.68
# Process 1, Episode 130, Total Reward: -230.58, Average Score: -141.75
# Process 0, Episode 140, Total Reward: -92.61, Average Score: -150.70
# Process 3, Episode 140, Total Reward: -124.23, Average Score: -144.59
# Process 4, Episode 140, Total Reward: -89.16, Average Score: -146.82
# Process 2, Episode 140, Total Reward: -185.22, Average Score: -145.64
# Process 5, Episode 140, Total Reward: -89.73, Average Score: -147.59
# Process 7, Episode 140, Total Reward: -81.35, Average Score: -153.09
# Process 1, Episode 140, Total Reward: -95.82, Average Score: -139.81
# Process 6, Episode 140, Total Reward: -29.91, Average Score: -142.84
# Process 0, Episode 150, Total Reward: -240.56, Average Score: -146.70
# Process 4, Episode 150, Total Reward: -129.22, Average Score: -140.56
# Process 3, Episode 150, Total Reward: -184.79, Average Score: -136.91
# Process 2, Episode 150, Total Reward: -218.73, Average Score: -140.79
# Process 5, Episode 150, Total Reward: -75.72, Average Score: -142.80
# Process 1, Episode 150, Total Reward: -82.52, Average Score: -133.84
# Process 7, Episode 150, Total Reward: -170.85, Average Score: -148.27
# Process 6, Episode 150, Total Reward: -66.83, Average Score: -138.17
# Process 0, Episode 160, Total Reward: -101.19, Average Score: -139.78
# Process 4, Episode 160, Total Reward: -144.57, Average Score: -132.28
# Process 2, Episode 160, Total Reward: -130.42, Average Score: -138.78
# Process 5, Episode 160, Total Reward: -77.81, Average Score: -132.41
# Process 6, Episode 160, Total Reward: -119.41, Average Score: -135.58
# Process 1, Episode 160, Total Reward: -110.07, Average Score: -129.44
# Process 7, Episode 160, Total Reward: -106.85, Average Score: -147.89
# Process 0, Episode 170, Total Reward: -59.59, Average Score: -140.47
# Process 3, Episode 160, Total Reward: -106.71, Average Score: -135.13
# Process 4, Episode 170, Total Reward: -106.43, Average Score: -135.55
# Process 2, Episode 170, Total Reward: -113.22, Average Score: -131.93
# Process 5, Episode 170, Total Reward: -105.59, Average Score: -125.41
# Process 6, Episode 170, Total Reward: -90.67, Average Score: -127.12
# Process 1, Episode 170, Total Reward: -134.32, Average Score: -122.01
# Process 7, Episode 170, Total Reward: -118.29, Average Score: -147.67
# Process 3, Episode 170, Total Reward: -105.40, Average Score: -128.75
# Process 0, Episode 180, Total Reward: -119.35, Average Score: -136.23
# Process 4, Episode 180, Total Reward: -82.93, Average Score: -132.53
# Process 2, Episode 180, Total Reward: -0.80, Average Score: -132.79
# Process 1, Episode 180, Total Reward: -130.76, Average Score: -113.77
# Process 6, Episode 180, Total Reward: -91.87, Average Score: -120.43
# Process 5, Episode 180, Total Reward: -308.28, Average Score: -127.92
# Process 7, Episode 180, Total Reward: -159.45, Average Score: -143.15
# Process 0, Episode 190, Total Reward: -103.94, Average Score: -134.23
# Process 3, Episode 180, Total Reward: -97.66, Average Score: -126.42
# Process 4, Episode 190, Total Reward: -77.14, Average Score: -132.89
# Process 2, Episode 190, Total Reward: -85.26, Average Score: -131.10
# Process 1, Episode 190, Total Reward: -62.13, Average Score: -113.82
# Process 6, Episode 190, Total Reward: -62.63, Average Score: -115.89
# Process 5, Episode 190, Total Reward: -98.31, Average Score: -125.30
# Process 7, Episode 190, Total Reward: -81.57, Average Score: -135.44
# Process 0, Episode 200, Total Reward: -104.95, Average Score: -135.62
# Process 3, Episode 190, Total Reward: -110.54, Average Score: -129.33
# Process 4, Episode 200, Total Reward: -117.27, Average Score: -128.90
# Process 2, Episode 200, Total Reward: -99.56, Average Score: -128.59
# Process 1, Episode 200, Total Reward: -153.98, Average Score: -115.25
# Process 6, Episode 200, Total Reward: -122.28, Average Score: -114.57
# Process 5, Episode 200, Total Reward: -101.02, Average Score: -121.07
# Process 7, Episode 200, Total Reward: -235.02, Average Score: -128.67
# Process 0, Episode 210, Total Reward: -96.91, Average Score: -131.36
# Process 3, Episode 200, Total Reward: -513.53, Average Score: -126.85
# Process 4, Episode 210, Total Reward: -85.36, Average Score: -126.10
# Process 2, Episode 210, Total Reward: -145.79, Average Score: -129.58
# Process 1, Episode 210, Total Reward: -98.89, Average Score: -112.46
# Process 6, Episode 210, Total Reward: -92.62, Average Score: -119.81
# Process 5, Episode 210, Total Reward: -183.86, Average Score: -120.74
# Process 7, Episode 210, Total Reward: -70.17, Average Score: -130.17
# Process 0, Episode 220, Total Reward: -175.71, Average Score: -127.79
# Process 3, Episode 210, Total Reward: -116.12, Average Score: -119.84
# Process 4, Episode 220, Total Reward: -110.39, Average Score: -123.59
# Process 1, Episode 220, Total Reward: -151.06, Average Score: -108.93
# Process 2, Episode 220, Total Reward: -157.18, Average Score: -124.62
# Process 6, Episode 220, Total Reward: -119.01, Average Score: -119.67
# Process 7, Episode 220, Total Reward: -148.08, Average Score: -123.09
# Process 5, Episode 220, Total Reward: -14.70, Average Score: -119.72
# Process 0, Episode 230, Total Reward: -62.80, Average Score: -123.62
# Process 3, Episode 220, Total Reward: -107.80, Average Score: -120.06
# Process 1, Episode 230, Total Reward: -103.05, Average Score: -107.75
# Process 4, Episode 230, Total Reward: -87.12, Average Score: -116.63
# Process 2, Episode 230, Total Reward: -139.36, Average Score: -122.41
# Process 6, Episode 230, Total Reward: -86.07, Average Score: -120.42
# Process 7, Episode 230, Total Reward: -128.28, Average Score: -122.34
# Process 0, Episode 240, Total Reward: -96.48, Average Score: -126.89
# Process 5, Episode 230, Total Reward: -92.16, Average Score: -114.29
# Process 3, Episode 230, Total Reward: -309.87, Average Score: -115.58
# Process 1, Episode 240, Total Reward: -145.18, Average Score: -105.98
# Process 4, Episode 240, Total Reward: -144.08, Average Score: -114.27
# Process 2, Episode 240, Total Reward: -81.20, Average Score: -119.08
# Process 6, Episode 240, Total Reward: -18.73, Average Score: -119.58
# Process 7, Episode 240, Total Reward: -71.71, Average Score: -120.07
# Process 0, Episode 250, Total Reward: -91.39, Average Score: -124.98
# Process 5, Episode 240, Total Reward: -140.69, Average Score: -112.56
# Process 3, Episode 240, Total Reward: -78.66, Average Score: -113.73
# Process 4, Episode 250, Total Reward: -162.47, Average Score: -113.11
# Process 1, Episode 250, Total Reward: -105.60, Average Score: -105.01
# Process 2, Episode 250, Total Reward: -103.08, Average Score: -115.99
# Process 6, Episode 250, Total Reward: -86.04, Average Score: -116.26
# Process 0, Episode 260, Total Reward: -76.38, Average Score: -122.47
# Process 7, Episode 250, Total Reward: -83.37, Average Score: -115.59
# Process 5, Episode 250, Total Reward: -93.75, Average Score: -112.23
# Process 3, Episode 250, Total Reward: -80.52, Average Score: -113.92
# Process 4, Episode 260, Total Reward: -78.56, Average Score: -111.15
# Process 1, Episode 260, Total Reward: -118.67, Average Score: -103.12
# Process 2, Episode 260, Total Reward: -95.22, Average Score: -111.02
# Process 6, Episode 260, Total Reward: -20.80, Average Score: -117.12
# Process 7, Episode 260, Total Reward: -76.51, Average Score: -111.33
# Process 0, Episode 270, Total Reward: -105.25, Average Score: -116.93
# Process 4, Episode 270, Total Reward: -76.28, Average Score: -106.88
# Process 5, Episode 260, Total Reward: -83.88, Average Score: -112.33
# Process 3, Episode 260, Total Reward: -126.87, Average Score: -111.29
# Process 2, Episode 270, Total Reward: -56.63, Average Score: -109.67
# Process 1, Episode 270, Total Reward: -203.76, Average Score: -105.22
# Process 6, Episode 270, Total Reward: -59.20, Average Score: -116.92
# Process 0, Episode 280, Total Reward: -59.51, Average Score: -111.19
# Process 7, Episode 270, Total Reward: -71.77, Average Score: -108.93
# Process 4, Episode 280, Total Reward: -125.17, Average Score: -106.21
# Process 2, Episode 280, Total Reward: -84.98, Average Score: -105.12
# Process 3, Episode 270, Total Reward: -115.61, Average Score: -115.82
# Process 5, Episode 270, Total Reward: -113.41, Average Score: -110.35
# Process 1, Episode 280, Total Reward: -140.03, Average Score: -103.52
# Process 6, Episode 280, Total Reward: -77.70, Average Score: -114.27
# Process 7, Episode 280, Total Reward: -97.87, Average Score: -106.34
# Process 0, Episode 290, Total Reward: -11.80, Average Score: -105.98
# Process 4, Episode 290, Total Reward: -83.66, Average Score: -102.28
# Process 2, Episode 290, Total Reward: -20.19, Average Score: -102.63
# Process 3, Episode 280, Total Reward: -249.21, Average Score: -114.18
# Process 5, Episode 280, Total Reward: -94.67, Average Score: -107.58
# Process 6, Episode 290, Total Reward: -82.93, Average Score: -113.71
# Process 1, Episode 290, Total Reward: -218.64, Average Score: -103.35
# Process 0, Episode 300, Total Reward: -66.78, Average Score: -101.75
# Process 7, Episode 290, Total Reward: -62.46, Average Score: -106.02
# Process 3, Episode 290, Total Reward: -75.40, Average Score: -110.17
# Process 5, Episode 290, Total Reward: -57.12, Average Score: -105.20
# Process 2, Episode 300, Total Reward: -67.37, Average Score: -97.25
# Process 4, Episode 300, Total Reward: -102.51, Average Score: -101.37
# Process 6, Episode 300, Total Reward: -48.09, Average Score: -110.98
# Process 1, Episode 300, Total Reward: -57.24, Average Score: -98.91
# Process 0, Episode 310, Total Reward: -12.16, Average Score: -94.49
# Process 7, Episode 300, Total Reward: -56.11, Average Score: -100.77
# Process 3, Episode 300, Total Reward: -41.63, Average Score: -103.80
# Process 5, Episode 300, Total Reward: -89.73, Average Score: -100.34
# Process 4, Episode 310, Total Reward: -114.84, Average Score: -99.25
# Process 1, Episode 310, Total Reward: -184.21, Average Score: -96.92
# Process 6, Episode 310, Total Reward: -57.10, Average Score: -105.51
# Process 2, Episode 310, Total Reward: -116.53, Average Score: -88.22
# Process 3, Episode 310, Total Reward: -109.07, Average Score: -102.03
# Process 0, Episode 320, Total Reward: -40.93, Average Score: -90.31
# Process 4, Episode 320, Total Reward: -105.66, Average Score: -96.03
# Process 5, Episode 310, Total Reward: -126.35, Average Score: -96.33
# Process 1, Episode 320, Total Reward: -38.15, Average Score: -90.64
# Process 7, Episode 310, Total Reward: -86.41, Average Score: -97.18
# Process 3, Episode 320, Total Reward: -67.40, Average Score: -98.65
# Process 2, Episode 320, Total Reward: -91.35, Average Score: -86.07
# Process 0, Episode 330, Total Reward: -157.97, Average Score: -88.62
# Process 5, Episode 320, Total Reward: -77.63, Average Score: -92.81
# Process 4, Episode 330, Total Reward: -57.30, Average Score: -93.57
# Process 6, Episode 320, Total Reward: -19.44, Average Score: -98.34
# Process 1, Episode 330, Total Reward: -85.99, Average Score: -88.41
# Process 7, Episode 320, Total Reward: -69.66, Average Score: -94.17
# Process 2, Episode 330, Total Reward: -82.72, Average Score: -86.61
# Process 3, Episode 330, Total Reward: -29.62, Average Score: -97.03
# Process 0, Episode 340, Total Reward: 6.00, Average Score: -84.20
# Process 4, Episode 340, Total Reward: -87.53, Average Score: -91.23
# Process 5, Episode 330, Total Reward: -44.29, Average Score: -88.20
# Process 6, Episode 330, Total Reward: -103.83, Average Score: -100.30
# Process 1, Episode 340, Total Reward: -102.16, Average Score: -85.87
# Process 7, Episode 330, Total Reward: -117.47, Average Score: -93.81
# Process 3, Episode 340, Total Reward: -79.90, Average Score: -97.14
# Process 2, Episode 340, Total Reward: -149.67, Average Score: -82.94
# Process 0, Episode 350, Total Reward: -83.52, Average Score: -82.56
# Process 4, Episode 350, Total Reward: -117.14, Average Score: -86.99
# Process 5, Episode 340, Total Reward: 1.97, Average Score: -86.91
# Process 1, Episode 350, Total Reward: -91.89, Average Score: -86.00
# Process 6, Episode 340, Total Reward: -65.50, Average Score: -92.39
# Process 7, Episode 340, Total Reward: -98.61, Average Score: -92.50
# Process 0, Episode 360, Total Reward: -50.34, Average Score: -80.78
# Process 3, Episode 350, Total Reward: -63.07, Average Score: -93.56
# Process 4, Episode 360, Total Reward: -53.54, Average Score: -86.19
# Process 5, Episode 350, Total Reward: -68.28, Average Score: -82.38
# Process 1, Episode 360, Total Reward: -107.12, Average Score: -85.03
# Process 6, Episode 350, Total Reward: -97.54, Average Score: -90.40
# Process 2, Episode 350, Total Reward: 30.73, Average Score: -81.16
# Process 7, Episode 350, Total Reward: -31.40, Average Score: -91.38
# Process 0, Episode 370, Total Reward: -286.32, Average Score: -81.84
# Process 3, Episode 360, Total Reward: -46.24, Average Score: -90.96
# Process 4, Episode 370, Total Reward: -157.48, Average Score: -84.50
# Process 1, Episode 370, Total Reward: -35.57, Average Score: -81.67
# Process 5, Episode 360, Total Reward: -36.50, Average Score: -81.47
# Process 6, Episode 360, Total Reward: -61.04, Average Score: -86.98
# Process 0, Episode 380, Total Reward: -70.30, Average Score: -79.70
# Process 3, Episode 370, Total Reward: -89.85, Average Score: -85.41
# Process 2, Episode 360, Total Reward: -94.73, Average Score: -81.48
# Process 7, Episode 360, Total Reward: -98.68, Average Score: -89.86
# Process 4, Episode 380, Total Reward: -29.10, Average Score: -81.28
# Process 1, Episode 380, Total Reward: -28.99, Average Score: -79.25
# Process 5, Episode 370, Total Reward: -62.56, Average Score: -76.55
# Process 6, Episode 370, Total Reward: -79.52, Average Score: -83.01
# Process 0, Episode 390, Total Reward: -39.20, Average Score: -80.03
# Process 3, Episode 380, Total Reward: -87.86, Average Score: -81.04
# Process 2, Episode 370, Total Reward: -64.62, Average Score: -81.40
# Process 7, Episode 370, Total Reward: -73.22, Average Score: -87.73
# Process 4, Episode 390, Total Reward: -38.06, Average Score: -80.32
# Process 1, Episode 390, Total Reward: -79.01, Average Score: -76.50
# Process 6, Episode 380, Total Reward: -73.14, Average Score: -80.69
# Process 5, Episode 380, Total Reward: -101.70, Average Score: -72.03
# Process 0, Episode 400, Total Reward: -24.42, Average Score: -76.85
# Process 7, Episode 380, Total Reward: -82.75, Average Score: -88.12
# Process 4, Episode 400, Total Reward: -100.25, Average Score: -80.68
# Process 3, Episode 390, Total Reward: -273.07, Average Score: -81.26
# Process 6, Episode 390, Total Reward: -70.19, Average Score: -77.34
# Process 1, Episode 400, Total Reward: -74.53, Average Score: -77.49
# Process 2, Episode 380, Total Reward: -59.36, Average Score: -78.35
# Process 5, Episode 390, Total Reward: -15.89, Average Score: -69.62
# Process 7, Episode 390, Total Reward: -69.13, Average Score: -86.70
# Process 0, Episode 410, Total Reward: -70.12, Average Score: -76.63
# Process 4, Episode 410, Total Reward: -0.24, Average Score: -77.96
# Process 3, Episode 400, Total Reward: -81.52, Average Score: -79.72
# Process 1, Episode 410, Total Reward: -84.78, Average Score: -74.81
# Process 6, Episode 400, Total Reward: -77.58, Average Score: -73.57
# Process 2, Episode 390, Total Reward: -26.01, Average Score: -77.72
# Process 7, Episode 400, Total Reward: -49.31, Average Score: -85.62
# Process 5, Episode 400, Total Reward: -114.60, Average Score: -71.02
# Process 4, Episode 420, Total Reward: -79.93, Average Score: -76.56
# Process 7, Episode 410, Total Reward: -46.98, Average Score: -81.02
# Process 3, Episode 410, Total Reward: -22.12, Average Score: -76.42
# Process 1, Episode 420, Total Reward: -74.89, Average Score: -77.22
# Process 2, Episode 400, Total Reward: -74.20, Average Score: -79.22
# Process 0, Episode 420, Total Reward: -111.03, Average Score: -73.40
# Process 5, Episode 410, Total Reward: -134.93, Average Score: -68.40
# Process 4, Episode 430, Total Reward: -85.62, Average Score: -77.53
# Process 6, Episode 410, Total Reward: -79.98, Average Score: -71.94
# Process 3, Episode 420, Total Reward: -61.13, Average Score: -76.59
# Process 7, Episode 420, Total Reward: -65.68, Average Score: -78.93
# Process 2, Episode 410, Total Reward: 15.34, Average Score: -80.62
# Process 1, Episode 430, Total Reward: -77.52, Average Score: -76.22
# Process 0, Episode 430, Total Reward: -7.48, Average Score: -72.93
# Process 5, Episode 420, Total Reward: -26.42, Average Score: -66.34
# Process 4, Episode 440, Total Reward: -62.93, Average Score: -75.90
# Process 3, Episode 430, Total Reward: -117.51, Average Score: -76.29
# Process 6, Episode 420, Total Reward: -114.80, Average Score: -72.86
# Process 2, Episode 420, Total Reward: -102.44, Average Score: -79.06
# Process 1, Episode 440, Total Reward: -200.40, Average Score: -75.93
# Process 0, Episode 440, Total Reward: -63.82, Average Score: -74.48
# Process 4, Episode 450, Total Reward: -158.23, Average Score: -77.59
# Process 7, Episode 430, Total Reward: -68.49, Average Score: -75.63
# Process 6, Episode 430, Total Reward: -120.25, Average Score: -71.56
# Process 5, Episode 430, Total Reward: -46.95, Average Score: -68.21
# Process 2, Episode 430, Total Reward: -21.56, Average Score: -74.93
# Process 1, Episode 450, Total Reward: -63.84, Average Score: -72.77
# Process 0, Episode 450, Total Reward: -8.77, Average Score: -71.72
# Process 3, Episode 440, Total Reward: -66.24, Average Score: -73.74
# Process 4, Episode 460, Total Reward: -3.59, Average Score: -76.19
# Process 5, Episode 440, Total Reward: -44.54, Average Score: -69.74
# Process 6, Episode 440, Total Reward: -52.65, Average Score: -72.14
# Process 7, Episode 440, Total Reward: -107.05, Average Score: -76.01
# Process 2, Episode 440, Total Reward: 25.14, Average Score: -72.58
# Process 1, Episode 460, Total Reward: -189.50, Average Score: -73.66
# Process 3, Episode 450, Total Reward: -31.66, Average Score: -72.93
# Process 4, Episode 470, Total Reward: 42.65, Average Score: -73.04
# Process 5, Episode 450, Total Reward: -78.08, Average Score: -71.18
# Process 7, Episode 450, Total Reward: -5.80, Average Score: -75.78
# Process 2, Episode 450, Total Reward: -103.81, Average Score: -72.25
# Process 0, Episode 460, Total Reward: -65.99, Average Score: -69.00
# Process 1, Episode 470, Total Reward: -122.68, Average Score: -76.18
# Process 6, Episode 450, Total Reward: -84.74, Average Score: -70.03
# Process 4, Episode 480, Total Reward: -264.51, Average Score: -72.39
# Process 5, Episode 460, Total Reward: -81.32, Average Score: -74.08
# Process 7, Episode 460, Total Reward: -108.98, Average Score: -75.57
# Process 3, Episode 460, Total Reward: -57.83, Average Score: -70.86
# Process 2, Episode 460, Total Reward: -20.00, Average Score: -73.06
# Process 0, Episode 470, Total Reward: -23.59, Average Score: -67.05
# Process 4, Episode 490, Total Reward: -22.03, Average Score: -67.87
# Process 6, Episode 460, Total Reward: -56.88, Average Score: -69.62
# Process 1, Episode 480, Total Reward: -118.66, Average Score: -77.43
# Process 2, Episode 470, Total Reward: -35.27, Average Score: -69.59
# Process 7, Episode 470, Total Reward: -53.68, Average Score: -72.05
# Process 0, Episode 480, Total Reward: -141.97, Average Score: -67.93
# Process 3, Episode 470, Total Reward: 9.33, Average Score: -66.70
# Process 5, Episode 470, Total Reward: -121.22, Average Score: -78.24
# Process 4, Episode 500, Total Reward: -91.69, Average Score: -65.25
# Process 6, Episode 470, Total Reward: -61.05, Average Score: -69.61
# Process 2, Episode 480, Total Reward: -58.45, Average Score: -68.83
# Process 3, Episode 480, Total Reward: -29.97, Average Score: -67.52
# Process 1, Episode 490, Total Reward: -78.47, Average Score: -77.82
# Process 7, Episode 480, Total Reward: -45.88, Average Score: -71.15
# Process 4, Episode 510, Total Reward: -180.82, Average Score: -65.63
# Process 5, Episode 480, Total Reward: -87.35, Average Score: -76.88
# Process 3, Episode 490, Total Reward: -120.88, Average Score: -64.26
# Process 2, Episode 490, Total Reward: -172.07, Average Score: -67.60
# Process 6, Episode 480, Total Reward: -73.75, Average Score: -70.96
# Process 4, Episode 520, Total Reward: -60.80, Average Score: -66.28
# Process 5, Episode 490, Total Reward: -51.57, Average Score: -77.78
# Process 0, Episode 490, Total Reward: -100.25, Average Score: -66.62
# Process 1, Episode 500, Total Reward: -9.75, Average Score: -76.08
# Process 3, Episode 500, Total Reward: -94.67, Average Score: -61.61
# Process 7, Episode 490, Total Reward: -15.35, Average Score: -68.95
# Process 6, Episode 490, Total Reward: -101.74, Average Score: -75.47
# Process 0, Episode 500, Total Reward: -23.87, Average Score: -67.32
# Process 5, Episode 500, Total Reward: -105.31, Average Score: -85.40
# Process 3, Episode 510, Total Reward: -64.61, Average Score: -61.36
# Process 2, Episode 500, Total Reward: -76.52, Average Score: -64.58
# Process 1, Episode 510, Total Reward: -15.91, Average Score: -75.62
# Process 6, Episode 500, Total Reward: -110.97, Average Score: -77.53
# Process 7, Episode 500, Total Reward: -104.96, Average Score: -72.04
# Process 4, Episode 530, Total Reward: -130.80, Average Score: -66.20
# Process 5, Episode 510, Total Reward: -67.35, Average Score: -86.89
# Process 0, Episode 510, Total Reward: -31.52, Average Score: -65.25
# Process 3, Episode 520, Total Reward: -95.67, Average Score: -61.41
# Process 2, Episode 510, Total Reward: -35.45, Average Score: -63.64
# Process 1, Episode 520, Total Reward: -54.08, Average Score: -72.80
# Process 6, Episode 510, Total Reward: -25.91, Average Score: -75.15
# Process 2, Episode 520, Total Reward: -77.52, Average Score: -62.82
# Process 7, Episode 510, Total Reward: -48.64, Average Score: -75.10
# Process 4, Episode 540, Total Reward: 7.61, Average Score: -65.58
# Process 0, Episode 520, Total Reward: -100.19, Average Score: -66.08
# Process 3, Episode 530, Total Reward: -107.14, Average Score: -59.18
# Process 5, Episode 520, Total Reward: -14.00, Average Score: -87.00
# Process 7, Episode 520, Total Reward: -63.02, Average Score: -74.81
# Process 4, Episode 550, Total Reward: -39.86, Average Score: -66.38
# Process 0, Episode 530, Total Reward: -109.14, Average Score: -66.44
# Process 6, Episode 520, Total Reward: -23.98, Average Score: -76.57
# Process 1, Episode 530, Total Reward: -58.35, Average Score: -74.31
# Process 2, Episode 530, Total Reward: -230.53, Average Score: -67.53
# Process 3, Episode 540, Total Reward: -43.39, Average Score: -59.63
# Process 5, Episode 530, Total Reward: -35.13, Average Score: -87.04
# Process 7, Episode 530, Total Reward: -204.42, Average Score: -78.25
# Process 4, Episode 560, Total Reward: -62.47, Average Score: -63.34
# Process 6, Episode 530, Total Reward: -170.83, Average Score: -76.59
# Process 0, Episode 540, Total Reward: -48.81, Average Score: -67.16
# Process 1, Episode 540, Total Reward: -109.89, Average Score: -73.28
# Process 2, Episode 540, Total Reward: 5.13, Average Score: -70.21
# Process 4, Episode 570, Total Reward: -41.87, Average Score: -64.14
# Process 5, Episode 540, Total Reward: -79.23, Average Score: -86.63
# Process 3, Episode 550, Total Reward: -62.96, Average Score: -62.44
# Process 0, Episode 550, Total Reward: -76.32, Average Score: -67.82
# Process 2, Episode 550, Total Reward: -90.49, Average Score: -69.51
# Process 7, Episode 540, Total Reward: 1.70, Average Score: -75.01
# Process 6, Episode 540, Total Reward: 12.84, Average Score: -75.16
# Process 4, Episode 580, Total Reward: -191.36, Average Score: -65.58
# Process 3, Episode 560, Total Reward: -208.15, Average Score: -66.68
# Process 1, Episode 550, Total Reward: -121.35, Average Score: -78.55
# Process 5, Episode 550, Total Reward: -101.68, Average Score: -84.11
# Process 0, Episode 560, Total Reward: -228.28, Average Score: -71.14
# Process 7, Episode 550, Total Reward: -34.02, Average Score: -76.99
# Process 4, Episode 590, Total Reward: -132.18, Average Score: -68.51
# Process 6, Episode 550, Total Reward: -48.46, Average Score: -74.38
# Process 2, Episode 560, Total Reward: -163.51, Average Score: -68.16
# Process 0, Episode 570, Total Reward: -30.93, Average Score: -70.28
# Process 7, Episode 560, Total Reward: -276.40, Average Score: -77.31
# Process 3, Episode 570, Total Reward: -185.70, Average Score: -71.25
# Process 5, Episode 560, Total Reward: -114.53, Average Score: -81.65
# Process 6, Episode 560, Total Reward: -44.36, Average Score: -72.53
# Process 2, Episode 570, Total Reward: -1.17, Average Score: -65.25
# Process 1, Episode 560, Total Reward: -152.78, Average Score: -74.16
# Process 0, Episode 580, Total Reward: -87.73, Average Score: -71.14
# Process 4, Episode 600, Total Reward: -144.64, Average Score: -67.70
# Process 5, Episode 570, Total Reward: -22.00, Average Score: -75.04
# Process 1, Episode 570, Total Reward: 5.24, Average Score: -69.99
# Process 6, Episode 570, Total Reward: -86.33, Average Score: -74.02
# Process 3, Episode 580, Total Reward: -6.50, Average Score: -66.67
# Process 7, Episode 570, Total Reward: -81.45, Average Score: -78.78
# Process 1, Episode 580, Total Reward: -122.34, Average Score: -69.17
# Process 4, Episode 610, Total Reward: -87.93, Average Score: -64.59
# Process 6, Episode 580, Total Reward: -184.43, Average Score: -73.96
# Process 0, Episode 590, Total Reward: -177.64, Average Score: -70.67
# Process 5, Episode 580, Total Reward: -18.46, Average Score: -78.03
# Process 2, Episode 580, Total Reward: 8.02, Average Score: -64.27
# Process 3, Episode 590, Total Reward: 9.15, Average Score: -68.90
# Process 1, Episode 590, Total Reward: -38.56, Average Score: -68.23
# Process 4, Episode 620, Total Reward: -69.49, Average Score: -59.97
# Process 5, Episode 590, Total Reward: -21.61, Average Score: -78.18
# Process 6, Episode 590, Total Reward: -55.66, Average Score: -66.15
# Process 7, Episode 580, Total Reward: -3.20, Average Score: -76.99
# Process 3, Episode 600, Total Reward: -99.58, Average Score: -70.61
# Process 4, Episode 630, Total Reward: -84.11, Average Score: -59.73
# Process 0, Episode 600, Total Reward: -37.54, Average Score: -73.98
# Process 6, Episode 600, Total Reward: -79.10, Average Score: -62.71
# Process 1, Episode 600, Total Reward: -198.39, Average Score: -68.67
# Process 2, Episode 590, Total Reward: -68.42, Average Score: -62.27
# Process 5, Episode 600, Total Reward: -91.68, Average Score: -68.67
# Process 6, Episode 610, Total Reward: -127.69, Average Score: -61.59
# Process 7, Episode 590, Total Reward: 23.06, Average Score: -75.28
# Process 4, Episode 640, Total Reward: -54.84, Average Score: -59.40
# Process 3, Episode 610, Total Reward: -68.00, Average Score: -70.71
# Process 0, Episode 610, Total Reward: -189.00, Average Score: -76.86
# Process 1, Episode 610, Total Reward: -40.62, Average Score: -68.51
# Process 2, Episode 600, Total Reward: -36.88, Average Score: -64.29
# Process 6, Episode 620, Total Reward: -119.60, Average Score: -58.70
# Process 0, Episode 620, Total Reward: -48.82, Average Score: -72.70
# Process 5, Episode 610, Total Reward: -81.36, Average Score: -64.96
# Process 7, Episode 600, Total Reward: -33.05, Average Score: -70.78
# Process 3, Episode 620, Total Reward: -28.35, Average Score: -69.31
# Process 1, Episode 620, Total Reward: -40.94, Average Score: -68.06
# Process 6, Episode 630, Total Reward: -16.10, Average Score: -56.75
# Process 4, Episode 650, Total Reward: -254.59, Average Score: -58.77
# Process 2, Episode 610, Total Reward: -65.52, Average Score: -61.57
# Process 0, Episode 630, Total Reward: -47.23, Average Score: -71.51
# Process 7, Episode 610, Total Reward: -144.76, Average Score: -69.53
# Process 5, Episode 620, Total Reward: -205.75, Average Score: -64.11
# Process 3, Episode 630, Total Reward: -24.02, Average Score: -70.71
# Process 2, Episode 620, Total Reward: -5.60, Average Score: -60.20
# Process 6, Episode 640, Total Reward: -34.11, Average Score: -57.55
# Process 4, Episode 660, Total Reward: -59.25, Average Score: -61.49
# Process 0, Episode 640, Total Reward: -93.06, Average Score: -67.43
# Process 1, Episode 630, Total Reward: -86.99, Average Score: -66.89
# Process 5, Episode 630, Total Reward: -153.88, Average Score: -60.12
# Process 3, Episode 640, Total Reward: -56.75, Average Score: -71.00
# Process 7, Episode 620, Total Reward: -63.17, Average Score: -66.21
# Process 2, Episode 630, Total Reward: -118.65, Average Score: -58.95
# Process 5, Episode 640, Total Reward: 26.61, Average Score: -58.62
# Process 4, Episode 670, Total Reward: -121.30, Average Score: -61.45
# Process 6, Episode 650, Total Reward: -27.53, Average Score: -57.68
# Process 7, Episode 630, Total Reward: -34.63, Average Score: -61.02
# Process 3, Episode 650, Total Reward: -23.43, Average Score: -67.26
# Process 5, Episode 650, Total Reward: -21.64, Average Score: -55.92
# Process 2, Episode 640, Total Reward: -42.61, Average Score: -56.01
# Process 4, Episode 680, Total Reward: -53.42, Average Score: -59.07
# Process 0, Episode 650, Total Reward: -73.41, Average Score: -71.12
# Process 1, Episode 640, Total Reward: 20.41, Average Score: -63.29
# Process 6, Episode 660, Total Reward: 6.41, Average Score: -57.40
# Process 7, Episode 640, Total Reward: -36.03, Average Score: -59.53
# Process 4, Episode 690, Total Reward: -27.05, Average Score: -57.82
# Process 3, Episode 660, Total Reward: -259.08, Average Score: -62.70
# Process 0, Episode 660, Total Reward: -25.14, Average Score: -67.51
# Process 6, Episode 670, Total Reward: -96.87, Average Score: -57.84
# Process 1, Episode 650, Total Reward: -44.07, Average Score: -54.97
# Process 2, Episode 650, Total Reward: -146.18, Average Score: -52.24
# Process 7, Episode 650, Total Reward: -51.40, Average Score: -57.65
# Process 0, Episode 670, Total Reward: -41.36, Average Score: -71.51
# Process 1, Episode 660, Total Reward: -309.34, Average Score: -60.50
# Process 5, Episode 660, Total Reward: 36.19, Average Score: -52.60
# Process 4, Episode 700, Total Reward: -17.71, Average Score: -56.71
# Process 2, Episode 660, Total Reward: -19.63, Average Score: -47.57
# Process 3, Episode 670, Total Reward: -62.91, Average Score: -61.26
# Process 1, Episode 670, Total Reward: 17.25, Average Score: -58.73
# Process 6, Episode 680, Total Reward: -22.31, Average Score: -54.86
# Process 7, Episode 660, Total Reward: -0.58, Average Score: -54.46
# Process 5, Episode 670, Total Reward: -60.12, Average Score: -51.92
# Process 0, Episode 680, Total Reward: -43.79, Average Score: -68.55
# Process 2, Episode 670, Total Reward: -125.15, Average Score: -53.15
# Process 7, Episode 670, Total Reward: -84.75, Average Score: -51.24
# Process 1, Episode 680, Total Reward: 24.65, Average Score: -56.09
# Process 3, Episode 680, Total Reward: 17.20, Average Score: -62.82
# Process 6, Episode 690, Total Reward: -20.25, Average Score: -54.44
# Process 0, Episode 690, Total Reward: 138.54, Average Score: -68.29
# Process 4, Episode 710, Total Reward: 34.64, Average Score: -54.28
# Process 5, Episode 680, Total Reward: 94.31, Average Score: -43.23
# Process 3, Episode 690, Total Reward: -156.30, Average Score: -59.66
# Process 1, Episode 690, Total Reward: 13.62, Average Score: -49.27
# Process 7, Episode 680, Total Reward: -4.06, Average Score: -47.83
# Process 0, Episode 700, Total Reward: -68.48, Average Score: -62.95
# Process 2, Episode 680, Total Reward: 14.38, Average Score: -49.62
# Process 6, Episode 700, Total Reward: -53.52, Average Score: -57.81
# Process 4, Episode 720, Total Reward: -75.25, Average Score: -55.13
# Process 5, Episode 690, Total Reward: -19.82, Average Score: -42.24
# Process 3, Episode 700, Total Reward: -81.45, Average Score: -58.62
# Process 0, Episode 710, Total Reward: -186.72, Average Score: -70.28
# Process 7, Episode 690, Total Reward: -8.37, Average Score: -47.39
# Process 1, Episode 700, Total Reward: 0.95, Average Score: -52.87
# Process 5, Episode 700, Total Reward: 170.26, Average Score: -39.66
# Process 4, Episode 730, Total Reward: -182.65, Average Score: -51.77
# Process 2, Episode 690, Total Reward: 109.56, Average Score: -48.35
# Process 7, Episode 700, Total Reward: -39.77, Average Score: -48.59
# Process 6, Episode 710, Total Reward: -125.21, Average Score: -55.15
# Process 3, Episode 710, Total Reward: -157.15, Average Score: -55.28
# Process 5, Episode 710, Total Reward: -47.18, Average Score: -36.05
# Process 1, Episode 710, Total Reward: -10.09, Average Score: -47.00
# Process 4, Episode 740, Total Reward: 4.25, Average Score: -54.06
# Process 6, Episode 720, Total Reward: -4.74, Average Score: -52.02
# Process 3, Episode 720, Total Reward: 15.65, Average Score: -53.03
# Process 2, Episode 700, Total Reward: 110.76, Average Score: -41.96
# Process 7, Episode 710, Total Reward: 3.41, Average Score: -43.19
# Process 0, Episode 720, Total Reward: -22.07, Average Score: -71.34
# Process 5, Episode 720, Total Reward: -137.25, Average Score: -33.54
# Process 7, Episode 720, Total Reward: -18.24, Average Score: -44.41
# Process 6, Episode 730, Total Reward: 9.76, Average Score: -45.86
# Process 4, Episode 750, Total Reward: -61.82, Average Score: -45.41
# Process 3, Episode 730, Total Reward: 28.74, Average Score: -45.62
# Process 1, Episode 720, Total Reward: -14.16, Average Score: -42.43
# Process 2, Episode 710, Total Reward: 73.79, Average Score: -40.04
# Process 0, Episode 730, Total Reward: -110.36, Average Score: -66.76
# Process 1, Episode 730, Total Reward: -128.73, Average Score: -37.96
# Process 5, Episode 730, Total Reward: -54.24, Average Score: -27.57
# Process 6, Episode 740, Total Reward: 8.59, Average Score: -40.20
# Process 7, Episode 730, Total Reward: -67.27, Average Score: -40.57
# Process 3, Episode 740, Total Reward: -6.75, Average Score: -39.05
# Process 4, Episode 760, Total Reward: -20.08, Average Score: -36.00
# Process 0, Episode 740, Total Reward: 43.74, Average Score: -64.06
# Process 2, Episode 720, Total Reward: 121.16, Average Score: -33.44
# Process 5, Episode 740, Total Reward: -29.89, Average Score: -25.08
# Process 2, Episode 730, Total Reward: -111.85, Average Score: -26.21
# Process 3, Episode 750, Total Reward: -33.91, Average Score: -33.65
# Process 6, Episode 750, Total Reward: -3.66, Average Score: -33.68
# Process 4, Episode 770, Total Reward: 32.82, Average Score: -27.20
# Process 1, Episode 740, Total Reward: 130.86, Average Score: -35.72
# Process 7, Episode 740, Total Reward: -8.98, Average Score: -34.12
# Process 0, Episode 750, Total Reward: -33.20, Average Score: -53.48
# Process 5, Episode 750, Total Reward: -0.89, Average Score: -18.25
# Process 2, Episode 740, Total Reward: -57.88, Average Score: -25.47
# Process 3, Episode 760, Total Reward: 43.74, Average Score: -26.93
# Process 1, Episode 750, Total Reward: 102.02, Average Score: -36.57
# Process 6, Episode 760, Total Reward: 106.20, Average Score: -25.64
# Process 2, Episode 750, Total Reward: -48.55, Average Score: -24.13
# Process 0, Episode 760, Total Reward: -15.18, Average Score: -47.00
# Process 7, Episode 750, Total Reward: 45.49, Average Score: -20.97
# Process 4, Episode 780, Total Reward: -2.33, Average Score: -17.70
# Process 1, Episode 760, Total Reward: 11.28, Average Score: -26.46
# Process 5, Episode 760, Total Reward: -179.03, Average Score: -10.90
# Process 6, Episode 770, Total Reward: 55.82, Average Score: -13.07
# Process 3, Episode 770, Total Reward: 80.98, Average Score: -19.63
# Process 0, Episode 770, Total Reward: 69.55, Average Score: -37.51
# Process 7, Episode 760, Total Reward: -260.77, Average Score: -15.72
# Process 2, Episode 760, Total Reward: 98.37, Average Score: -20.76
# Process 4, Episode 790, Total Reward: -35.68, Average Score: -13.33
# Process 3, Episode 780, Total Reward: -220.02, Average Score: -18.22
# Process 1, Episode 770, Total Reward: -77.31, Average Score: -26.48
# Process 5, Episode 770, Total Reward: 69.53, Average Score: -11.60
# Process 2, Episode 770, Total Reward: 26.84, Average Score: -16.63
# Process 7, Episode 770, Total Reward: -48.83, Average Score: -14.50
# Process 6, Episode 780, Total Reward: -16.12, Average Score: -6.47
# Process 4, Episode 800, Total Reward: 3.73, Average Score: -6.76
# Process 3, Episode 790, Total Reward: 24.14, Average Score: -18.47
# Process 0, Episode 780, Total Reward: 74.32, Average Score: -31.93
# Process 1, Episode 780, Total Reward: 35.75, Average Score: -23.23
# Process 6, Episode 790, Total Reward: 27.50, Average Score: -6.23
# Process 5, Episode 780, Total Reward: 82.80, Average Score: -13.03
# Process 7, Episode 780, Total Reward: -44.32, Average Score: -15.97
# Process 2, Episode 780, Total Reward: 89.13, Average Score: -14.83
# Process 0, Episode 790, Total Reward: -41.09, Average Score: -27.72
# Process 3, Episode 800, Total Reward: 112.28, Average Score: -13.04
# Process 1, Episode 790, Total Reward: 19.32, Average Score: -23.82
# Process 5, Episode 790, Total Reward: -43.86, Average Score: -8.09
# Process 7, Episode 790, Total Reward: -29.98, Average Score: -9.69
# Process 2, Episode 790, Total Reward: -5.90, Average Score: -9.99
# Process 4, Episode 810, Total Reward: -29.16, Average Score: -4.71
# Process 0, Episode 800, Total Reward: -175.29, Average Score: -23.24
# Process 6, Episode 800, Total Reward: -12.87, Average Score: 6.46
# Process 1, Episode 800, Total Reward: -32.78, Average Score: -17.29
# Process 3, Episode 810, Total Reward: -206.90, Average Score: -15.04
# Process 5, Episode 800, Total Reward: 42.68, Average Score: -8.91
# Process 7, Episode 800, Total Reward: 102.74, Average Score: -2.48
# Process 4, Episode 820, Total Reward: 20.90, Average Score: -0.47
# Process 1, Episode 810, Total Reward: 80.76, Average Score: -15.74
# Process 0, Episode 810, Total Reward: -20.03, Average Score: -7.39
# Process 2, Episode 800, Total Reward: 103.02, Average Score: -7.93
# Process 6, Episode 810, Total Reward: 71.16, Average Score: 11.87
# Process 7, Episode 810, Total Reward: 95.77, Average Score: -1.73
# Process 5, Episode 810, Total Reward: 18.74, Average Score: -7.62
# Process 3, Episode 820, Total Reward: -53.55, Average Score: -6.51
# Process 1, Episode 820, Total Reward: 12.90, Average Score: -14.94
# Process 0, Episode 820, Total Reward: -58.64, Average Score: -2.89
# Process 2, Episode 810, Total Reward: 119.95, Average Score: -3.11
# Process 6, Episode 820, Total Reward: -193.46, Average Score: 9.72
# Process 7, Episode 820, Total Reward: 80.22, Average Score: 7.06
# Process 4, Episode 830, Total Reward: -57.27, Average Score: 7.24
# Process 5, Episode 820, Total Reward: -6.46, Average Score: -6.06
# Process 3, Episode 830, Total Reward: -180.11, Average Score: -6.58
# Process 0, Episode 830, Total Reward: -192.77, Average Score: -0.36
# Process 2, Episode 820, Total Reward: 19.39, Average Score: -7.69
# Process 4, Episode 840, Total Reward: -33.33, Average Score: 13.63
# Process 1, Episode 830, Total Reward: 105.42, Average Score: -9.03
# Process 2, Episode 830, Total Reward: 8.42, Average Score: -7.67
# Process 6, Episode 830, Total Reward: 134.03, Average Score: 8.17
# Process 7, Episode 830, Total Reward: 47.04, Average Score: 8.22
# Process 3, Episode 840, Total Reward: -40.19, Average Score: -9.59
# Process 0, Episode 840, Total Reward: -4.00, Average Score: -2.81
# Process 5, Episode 830, Total Reward: -123.56, Average Score: -5.68
# Process 4, Episode 850, Total Reward: -202.36, Average Score: 11.01
# Process 6, Episode 840, Total Reward: -57.14, Average Score: 1.97
# Process 2, Episode 840, Total Reward: -242.32, Average Score: -5.48
# Process 1, Episode 840, Total Reward: -29.66, Average Score: -11.74
# Process 3, Episode 850, Total Reward: 25.52, Average Score: -6.24
# Process 5, Episode 840, Total Reward: 69.73, Average Score: -3.91
# Process 0, Episode 850, Total Reward: -13.69, Average Score: -3.04
# Process 4, Episode 860, Total Reward: -12.74, Average Score: 11.25
# Process 7, Episode 840, Total Reward: 13.74, Average Score: 11.45
# Process 5, Episode 850, Total Reward: -39.43, Average Score: -9.20
# Process 2, Episode 850, Total Reward: 0.53, Average Score: -3.48
# Process 6, Episode 850, Total Reward: -1.83, Average Score: 1.97
# Process 3, Episode 860, Total Reward: 2.37, Average Score: -7.51
# Process 1, Episode 850, Total Reward: -20.54, Average Score: -8.48
# Process 0, Episode 860, Total Reward: -47.87, Average Score: -8.72
# Process 4, Episode 870, Total Reward: -136.76, Average Score: 8.67
# Process 2, Episode 860, Total Reward: -49.20, Average Score: -6.77
# Process 6, Episode 860, Total Reward: -80.13, Average Score: -3.52
# Process 7, Episode 850, Total Reward: 75.17, Average Score: 5.82
# Process 3, Episode 870, Total Reward: 42.35, Average Score: -4.79
# Process 4, Episode 880, Total Reward: 11.34, Average Score: 7.07
# Process 1, Episode 860, Total Reward: -155.78, Average Score: -9.17
# Process 5, Episode 860, Total Reward: 137.23, Average Score: -9.82
# Process 2, Episode 870, Total Reward: -173.71, Average Score: -1.51
# Process 6, Episode 870, Total Reward: 28.23, Average Score: -6.90
# Process 0, Episode 870, Total Reward: 104.30, Average Score: -6.32
# Process 1, Episode 870, Total Reward: -32.92, Average Score: -9.50
# Process 7, Episode 860, Total Reward: 105.21, Average Score: 7.77
# Process 2, Episode 880, Total Reward: 22.40, Average Score: -5.65
# Process 5, Episode 870, Total Reward: -61.22, Average Score: -8.62
# Process 6, Episode 880, Total Reward: 117.24, Average Score: -8.41
# Process 3, Episode 880, Total Reward: -142.72, Average Score: 0.16
# Process 4, Episode 890, Total Reward: 47.60, Average Score: 12.20
# ...
# Process 6, Episode 1420, Total Reward: 285.99, Average Score: 130.47
# Process 4, Episode 1390, Total Reward: 127.39, Average Score: 83.39
# Process 7, Episode 1410, Total Reward: 253.75, Average Score: 122.70
# Process 3, Episode 1410, Total Reward: 129.12, Average Score: 108.99
# Process 2, Episode 1440, Total Reward: 143.40, Average Score: 113.98
# Process 5, Episode 1400, Total Reward: 143.25, Average Score: 108.58
# Process 0, Episode 1430, Total Reward: 298.23, Average Score: 104.13
# Process 6, Episode 1430, Total Reward: 197.08, Average Score: 139.36
# Process 4, Episode 1400, Total Reward: 217.28, Average Score: 90.19
# Process 1, Episode 1430, Total Reward: 236.82, Average Score: 113.47
# Process 7, Episode 1420, Total Reward: 204.77, Average Score: 132.52
# Process 2, Episode 1450, Total Reward: 182.69, Average Score: 117.79
# Process 5, Episode 1410, Total Reward: 113.51, Average Score: 112.24
# Process 3, Episode 1420, Total Reward: 225.92, Average Score: 117.98
# Process 0, Episode 1440, Total Reward: 222.05, Average Score: 105.06
# Process 7, Episode 1430, Total Reward: 135.47, Average Score: 135.02
# Process 6, Episode 1440, Total Reward: 247.97, Average Score: 151.29
# Process 4, Episode 1410, Total Reward: 192.89, Average Score: 95.81
# Process 2, Episode 1460, Total Reward: 123.78, Average Score: 120.26
# Process 1, Episode 1440, Total Reward: 152.78, Average Score: 120.09
# Process 0, Episode 1450, Total Reward: 109.43, Average Score: 106.94
# Process 3, Episode 1430, Total Reward: 279.73, Average Score: 128.77
# Process 5, Episode 1420, Total Reward: 256.73, Average Score: 113.47
# Process 7, Episode 1440, Total Reward: 155.79, Average Score: 132.02
# Process 2, Episode 1470, Total Reward: 269.55, Average Score: 128.76
# Process 1, Episode 1450, Total Reward: 241.90, Average Score: 121.71
# Process 6, Episode 1450, Total Reward: 184.94, Average Score: 157.94
# Process 3, Episode 1440, Total Reward: 227.40, Average Score: 136.51
# Process 0, Episode 1460, Total Reward: 262.15, Average Score: 109.48
# Process 4, Episode 1420, Total Reward: 158.30, Average Score: 109.57
# Process 5, Episode 1430, Total Reward: 232.57, Average Score: 117.90
# Process 6, Episode 1460, Total Reward: 3.53, Average Score: 156.74
# Process 7, Episode 1450, Total Reward: 259.70, Average Score: 139.81
# Process 3, Episode 1450, Total Reward: 283.26, Average Score: 138.98
# Process 2, Episode 1480, Total Reward: 154.96, Average Score: 124.69
# Process 1, Episode 1460, Total Reward: 262.31, Average Score: 126.93
# Process 7, Episode 1460, Total Reward: 9.97, Average Score: 136.13
# Process 4, Episode 1430, Total Reward: 277.78, Average Score: 119.68
# Process 0, Episode 1470, Total Reward: 245.05, Average Score: 111.93
# Process 5, Episode 1440, Total Reward: 210.10, Average Score: 116.82
# Process 6, Episode 1470, Total Reward: 275.71, Average Score: 162.82
# Process 3, Episode 1460, Total Reward: 243.76, Average Score: 140.17
# Process 4, Episode 1440, Total Reward: -8.85, Average Score: 115.74
# Process 5, Episode 1450, Total Reward: 173.08, Average Score: 120.81
# Process 2, Episode 1490, Total Reward: 206.62, Average Score: 133.27
# Process 0, Episode 1480, Total Reward: 148.77, Average Score: 111.27
# Process 1, Episode 1470, Total Reward: 147.70, Average Score: 128.92
# Process 3, Episode 1470, Total Reward: 212.02, Average Score: 137.95
# Process 7, Episode 1470, Total Reward: 109.26, Average Score: 139.54
# Process 6, Episode 1480, Total Reward: 118.71, Average Score: 164.33
# Process 4, Episode 1450, Total Reward: 119.61, Average Score: 120.28
# Process 5, Episode 1460, Total Reward: 273.90, Average Score: 120.35
# Process 7, Episode 1480, Total Reward: 314.50, Average Score: 131.60
# Process 0, Episode 1490, Total Reward: 148.10, Average Score: 124.58
# Process 3, Episode 1480, Total Reward: 279.20, Average Score: 143.68
# Process 2, Episode 1500, Total Reward: -181.00, Average Score: 131.10
# Process 1, Episode 1480, Total Reward: 117.97, Average Score: 131.49
# Process 6, Episode 1490, Total Reward: -325.63, Average Score: 153.16
# Process 5, Episode 1470, Total Reward: 32.84, Average Score: 116.74
# Process 4, Episode 1460, Total Reward: 114.58, Average Score: 129.78
# Process 7, Episode 1490, Total Reward: 208.08, Average Score: 127.63
# Process 0, Episode 1500, Total Reward: 102.63, Average Score: 122.67
# Process 6, Episode 1500, Total Reward: 92.43, Average Score: 155.82
# Process 3, Episode 1490, Total Reward: 260.04, Average Score: 146.25
# Process 1, Episode 1490, Total Reward: 158.47, Average Score: 134.31
# Process 2, Episode 1510, Total Reward: 277.52, Average Score: 136.47
# Process 5, Episode 1480, Total Reward: -147.90, Average Score: 109.75
# Process 4, Episode 1470, Total Reward: 137.75, Average Score: 123.25
# Process 3, Episode 1500, Total Reward: 9.01, Average Score: 147.07
# Process 6, Episode 1510, Total Reward: -44.61, Average Score: 156.44
# Process 0, Episode 1510, Total Reward: 167.70, Average Score: 132.97
# Process 2, Episode 1520, Total Reward: 237.88, Average Score: 139.33
# Process 7, Episode 1500, Total Reward: 209.28, Average Score: 135.44
# Process 1, Episode 1500, Total Reward: 152.62, Average Score: 136.28
# Process 4, Episode 1480, Total Reward: -1.12, Average Score: 129.57
# Process 3, Episode 1510, Total Reward: 117.52, Average Score: 136.83
# Process 5, Episode 1490, Total Reward: 115.95, Average Score: 115.91
# Process 6, Episode 1520, Total Reward: -15.58, Average Score: 151.85
# Process 2, Episode 1530, Total Reward: 10.87, Average Score: 135.87
# Process 1, Episode 1510, Total Reward: 256.41, Average Score: 132.83
# Process 7, Episode 1510, Total Reward: 248.33, Average Score: 133.92
# Process 0, Episode 1520, Total Reward: 40.73, Average Score: 134.53
# Process 3, Episode 1520, Total Reward: -136.95, Average Score: 127.62
# Process 5, Episode 1500, Total Reward: 251.07, Average Score: 114.21
# Process 4, Episode 1490, Total Reward: 187.95, Average Score: 133.21
# Process 6, Episode 1530, Total Reward: 255.00, Average Score: 136.61
# Process 2, Episode 1540, Total Reward: 236.15, Average Score: 140.49
# Process 7, Episode 1520, Total Reward: 44.19, Average Score: 125.51
# Process 1, Episode 1520, Total Reward: 278.46, Average Score: 137.66
# Process 5, Episode 1510, Total Reward: -138.32, Average Score: 120.78
# Process 3, Episode 1530, Total Reward: 158.32, Average Score: 122.01
# Process 0, Episode 1530, Total Reward: 239.16, Average Score: 141.66
# Process 4, Episode 1500, Total Reward: 115.33, Average Score: 130.92
# Process 6, Episode 1540, Total Reward: 235.25, Average Score: 133.19
# Process 0, Episode 1540, Total Reward: 130.88, Average Score: 143.08
# Process 2, Episode 1550, Total Reward: 191.93, Average Score: 142.32
# Process 6, Episode 1550, Total Reward: 219.53, Average Score: 134.19
# Process 5, Episode 1520, Total Reward: 275.87, Average Score: 121.95
# Process 7, Episode 1530, Total Reward: 157.62, Average Score: 130.76
# Process 1, Episode 1530, Total Reward: -264.92, Average Score: 134.62
# Process 3, Episode 1540, Total Reward: -300.55, Average Score: 115.34
# Process 4, Episode 1510, Total Reward: -92.66, Average Score: 121.33
# Process 2, Episode 1560, Total Reward: 37.45, Average Score: 141.40
# Process 0, Episode 1550, Total Reward: 125.42, Average Score: 139.21
# Process 6, Episode 1560, Total Reward: 261.95, Average Score: 138.26
# Process 5, Episode 1530, Total Reward: 268.33, Average Score: 120.51
# Process 1, Episode 1540, Total Reward: 12.59, Average Score: 132.78
# Process 4, Episode 1520, Total Reward: -23.94, Average Score: 120.04
# Process 3, Episode 1550, Total Reward: 204.78, Average Score: 117.67
# Process 7, Episode 1540, Total Reward: 251.64, Average Score: 133.12
# Process 2, Episode 1570, Total Reward: 88.65, Average Score: 140.84
# Process 1, Episode 1550, Total Reward: 213.56, Average Score: 133.07
# Process 0, Episode 1560, Total Reward: 238.46, Average Score: 142.25
# Process 6, Episode 1570, Total Reward: 14.83, Average Score: 129.29
# Process 5, Episode 1540, Total Reward: 143.79, Average Score: 120.24
# Process 7, Episode 1550, Total Reward: 185.66, Average Score: 136.56
# Process 4, Episode 1530, Total Reward: 233.41, Average Score: 117.86
# Process 3, Episode 1560, Total Reward: 118.03, Average Score: 120.52
# Process 2, Episode 1580, Total Reward: 236.87, Average Score: 146.53
# Process 0, Episode 1570, Total Reward: 111.05, Average Score: 149.61
# Process 1, Episode 1560, Total Reward: 253.15, Average Score: 132.78
# Process 7, Episode 1560, Total Reward: 120.85, Average Score: 143.02
# Process 5, Episode 1550, Total Reward: 2.35, Average Score: 126.91
# Process 6, Episode 1580, Total Reward: 145.38, Average Score: 129.39
# Process 4, Episode 1540, Total Reward: 261.22, Average Score: 128.87
# Process 0, Episode 1580, Total Reward: 263.16, Average Score: 149.25
# Process 2, Episode 1590, Total Reward: 240.95, Average Score: 143.16
# Process 3, Episode 1570, Total Reward: 158.14, Average Score: 127.39
# Process 7, Episode 1570, Total Reward: 90.37, Average Score: 141.12
# Process 1, Episode 1570, Total Reward: 260.32, Average Score: 140.39
# Process 5, Episode 1560, Total Reward: 257.75, Average Score: 132.47
# Process 3, Episode 1580, Total Reward: 5.81, Average Score: 125.37
# Process 6, Episode 1590, Total Reward: 221.95, Average Score: 145.36
# Process 2, Episode 1600, Total Reward: 164.42, Average Score: 147.35
# Process 0, Episode 1590, Total Reward: 190.99, Average Score: 144.06
# Process 4, Episode 1550, Total Reward: 267.32, Average Score: 133.77
# Process 7, Episode 1580, Total Reward: 264.79, Average Score: 153.55
# Process 3, Episode 1590, Total Reward: 223.51, Average Score: 117.95
# Process 1, Episode 1580, Total Reward: 232.23, Average Score: 139.20
# Process 5, Episode 1570, Total Reward: 17.28, Average Score: 139.61
# Process 2, Episode 1610, Total Reward: 128.93, Average Score: 148.96
# Process 4, Episode 1560, Total Reward: 4.64, Average Score: 122.57
# Process 6, Episode 1600, Total Reward: 218.72, Average Score: 144.29
# Process 0, Episode 1600, Total Reward: 56.13, Average Score: 147.12
# Process 7, Episode 1590, Total Reward: 155.77, Average Score: 161.43
# Process 3, Episode 1600, Total Reward: -11.25, Average Score: 114.98
# Process 0, Episode 1610, Total Reward: -3.26, Average Score: 139.64
# Process 4, Episode 1570, Total Reward: 299.10, Average Score: 131.97
# Process 2, Episode 1620, Total Reward: 238.48, Average Score: 147.90
# Process 1, Episode 1590, Total Reward: 229.54, Average Score: 140.78
# Process 5, Episode 1580, Total Reward: -10.34, Average Score: 147.89
# Process 6, Episode 1610, Total Reward: 124.23, Average Score: 150.77
# Process 2, Episode 1630, Total Reward: 275.54, Average Score: 154.04
# Process 4, Episode 1580, Total Reward: 61.15, Average Score: 135.02
# Process 3, Episode 1610, Total Reward: 277.07, Average Score: 131.26
# Process 0, Episode 1620, Total Reward: -161.79, Average Score: 144.93
# Process 7, Episode 1600, Total Reward: 181.29, Average Score: 164.44
# Process 1, Episode 1600, Total Reward: 137.16, Average Score: 141.51
# Process 5, Episode 1590, Total Reward: 271.11, Average Score: 151.37
# Process 6, Episode 1620, Total Reward: 123.32, Average Score: 159.65
# Process 3, Episode 1620, Total Reward: 292.30, Average Score: 147.01
# Process 2, Episode 1640, Total Reward: 253.51, Average Score: 155.38
# Process 4, Episode 1590, Total Reward: 260.34, Average Score: 139.26
# Process 0, Episode 1630, Total Reward: 29.37, Average Score: 142.04
# Process 7, Episode 1610, Total Reward: 260.26, Average Score: 159.78
# Process 3, Episode 1630, Total Reward: 251.33, Average Score: 142.91
# Process 5, Episode 1600, Total Reward: 282.67, Average Score: 151.62
# Process 6, Episode 1630, Total Reward: 246.10, Average Score: 175.99
# Process 1, Episode 1610, Total Reward: 251.92, Average Score: 151.81
# Process 0, Episode 1640, Total Reward: 275.09, Average Score: 149.97
# Process 2, Episode 1650, Total Reward: 138.38, Average Score: 163.58
# Process 7, Episode 1620, Total Reward: 291.96, Average Score: 165.97
# Process 4, Episode 1600, Total Reward: 150.94, Average Score: 148.33
# Process 6, Episode 1640, Total Reward: 268.47, Average Score: 174.80
# Process 3, Episode 1640, Total Reward: 250.18, Average Score: 156.16
# Process 5, Episode 1610, Total Reward: 60.09, Average Score: 154.87
# Process 0, Episode 1650, Total Reward: 19.59, Average Score: 165.28
# Process 1, Episode 1620, Total Reward: -11.97, Average Score: 145.24
# Process 2, Episode 1660, Total Reward: 241.41, Average Score: 172.13
# Process 7, Episode 1630, Total Reward: -6.61, Average Score: 169.58
# Process 4, Episode 1610, Total Reward: 265.89, Average Score: 163.18
# Process 1, Episode 1630, Total Reward: 225.36, Average Score: 153.08
# Process 6, Episode 1650, Total Reward: -42.45, Average Score: 172.97
# Process 5, Episode 1620, Total Reward: 232.05, Average Score: 154.05
# Process 3, Episode 1650, Total Reward: 251.26, Average Score: 160.77
# Process 0, Episode 1660, Total Reward: 249.88, Average Score: 166.39
# Process 2, Episode 1670, Total Reward: 197.05, Average Score: 175.95
# Process 1, Episode 1640, Total Reward: 239.03, Average Score: 148.89
# Process 7, Episode 1640, Total Reward: 258.50, Average Score: 171.47
# Process 4, Episode 1620, Total Reward: 254.76, Average Score: 165.67
# Process 5, Episode 1630, Total Reward: 300.89, Average Score: 163.06
# Process 6, Episode 1660, Total Reward: -4.50, Average Score: 176.61
# Process 3, Episode 1660, Total Reward: 116.33, Average Score: 168.76
# Process 2, Episode 1680, Total Reward: 285.77, Average Score: 177.49
# Process 0, Episode 1670, Total Reward: 129.32, Average Score: 168.61
# Process 4, Episode 1630, Total Reward: 14.89, Average Score: 168.74
# Process 1, Episode 1650, Total Reward: 264.82, Average Score: 161.87
# Process 7, Episode 1650, Total Reward: 250.74, Average Score: 175.15
# Process 6, Episode 1670, Total Reward: 200.77, Average Score: 185.43
# Process 2, Episode 1690, Total Reward: 256.76, Average Score: 180.56
# Process 4, Episode 1640, Total Reward: 233.35, Average Score: 162.48
# Process 0, Episode 1680, Total Reward: 227.92, Average Score: 170.99
# Process 5, Episode 1640, Total Reward: 159.54, Average Score: 171.30
# Process 3, Episode 1670, Total Reward: 74.58, Average Score: 167.61
# Process 1, Episode 1660, Total Reward: 273.58, Average Score: 165.59
# Process 7, Episode 1660, Total Reward: 47.97, Average Score: 177.83
# Process 2, Episode 1700, Total Reward: 174.13, Average Score: 184.48
# Process 6, Episode 1680, Total Reward: 255.49, Average Score: 190.67
# Process 3, Episode 1680, Total Reward: 236.11, Average Score: 166.42
# Process 5, Episode 1650, Total Reward: 280.84, Average Score: 176.81
# Process 7, Episode 1670, Total Reward: 208.06, Average Score: 180.44
# Process 0, Episode 1690, Total Reward: 138.14, Average Score: 176.56
# Process 4, Episode 1650, Total Reward: 149.31, Average Score: 163.17
# Process 2, Episode 1710, Total Reward: 5.47, Average Score: 188.54
# Process 1, Episode 1670, Total Reward: 220.47, Average Score: 169.62
# Process 6, Episode 1690, Total Reward: 20.32, Average Score: 185.04
# Process 3, Episode 1690, Total Reward: 258.49, Average Score: 175.06
# Process 0, Episode 1700, Total Reward: 253.12, Average Score: 182.59
# Process 7, Episode 1680, Total Reward: 74.31, Average Score: 174.96
# Process 4, Episode 1660, Total Reward: 162.00, Average Score: 174.75
# Process 5, Episode 1660, Total Reward: 262.43, Average Score: 180.78
# Process 2, Episode 1720, Total Reward: 298.05, Average Score: 196.28
# Process 6, Episode 1700, Total Reward: 281.84, Average Score: 189.84
# Process 1, Episode 1680, Total Reward: 286.76, Average Score: 178.09
# Process 0, Episode 1710, Total Reward: 266.27, Average Score: 195.77
# Process 3, Episode 1700, Total Reward: 271.25, Average Score: 185.77
# Process 4, Episode 1670, Total Reward: 72.30, Average Score: 175.83
# Process 2, Episode 1730, Total Reward: 312.05, Average Score: 196.34
# Process 7, Episode 1690, Total Reward: 298.86, Average Score: 180.22
# Process 5, Episode 1670, Total Reward: 257.52, Average Score: 182.65
# Process 6, Episode 1710, Total Reward: 171.49, Average Score: 198.35
# Process 1, Episode 1690, Total Reward: 235.81, Average Score: 182.22
# Total Training Time: 4.06

# %%
env = gym.make('LunarLander-v3', render_mode="rgb_array")

state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# init agent
Q = QNetwork(state_size, action_size, hidden_size=128).to(device)

agent = Agent(
    state_size=state_size,
    action_size=action_size,
    Q_network=Q,
    gamma=0.995,
)

# load the weights from file
agent.Q.load_state_dict(torch.load('checkpoint.pth'))

env = gym.make("LunarLander-v3", render_mode="rgb_array")

avg_score = 0
for i in range(3):
	state, info = env.reset()
	total_reward = 0
	for t in range(500):
		# clear frame
		display.clear_output(wait=True)

		action = agent.select_action(state)

		# render game
		frame = env.render()
		display.display(Image.fromarray(frame))
		time.sleep(0.05)

		state, reward, done, _, info = env.step(action)
		total_reward += reward
		if done:
			break
	
	avg_score += total_reward
	print('Final score:', total_reward)
env.close()
print(f"Average score: {avg_score / 3}")
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>
# Final score: 296.06246995696023
# Average score: 235.299670766659

# %% [markdown]
# ### 8. Summary
#
#
# This implementation leverages an asynchronous parallel version of Deep Q-Learning, which eliminates the dependency on a replay buffer by using multiple processes to independently interact with the environment and update the shared Q-network. Compared to a traditional [Dueling DDQN](./dueling_ddqn_lunarlander.ipynb) implementation, which takes approximately **22 minutes** to solve the same task, this parallel version achieves a significant speedup. Running entirely on the **CPU**, it completes training in just **4.29 minutes**, demonstrating a **5x improvement in efficiency** while maintaining competitive performance. This acceleration is particularly beneficial for environments with computational constraints or limited access to GPUs.
