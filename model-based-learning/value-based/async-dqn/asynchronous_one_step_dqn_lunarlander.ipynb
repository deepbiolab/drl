# %% [markdown]
# # Asynchronous One Step Deep Q-Network (DQN)
#
# ### 0.Background: introduce Asynchronous to DQN
#
# Traditional **[Deep Q-Networks (DQN)](../vanilla-dqn/dqn_lunarlander.ipynb)** have been highly successful in solving reinforcement learning tasks by combining Q-learning with deep neural networks. However, they often require significant computational resources and suffer from stability issues during training. To address these challenges, **Asynchronous One Step DQN** introduces the concept of **asynchronous multi-threading**, where multiple agents (or threads) interact with their own copies of the environment in parallel. This approach provides several benefits:
#
# 1. **Improved computational efficiency**:
#    - By leveraging multiple threads, the algorithm can make better use of multi-core CPUs, enabling faster training without requiring expensive GPUs.
#
# 2. **Stabilized training**:
#    - Asynchronous updates reduce the correlation between consecutive updates, which helps mitigate the instability caused by highly correlated training data in traditional DQN.
#
# 3. **Enhanced exploration**:
#    - By assigning different exploration policies to each thread, Asynchronous DQN encourages diverse exploration, leading to better coverage of the state-action space.

# %% [markdown]
# ### 1. Import the Necessary Packages
#
# In this notebook, we will implement a DQN agent with OpenAI Gym's LunarLander-v2 environment.

# %%
import numpy as np
import gymnasium as gym
from collections import deque

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random

# for game rendering
import time
from PIL import Image
from IPython import display

device = torch.device("cpu")
print(f"Training on: {device}")

np.set_printoptions(precision=3, linewidth=120)
# Out:
# Training on: cpu

# %% [markdown]
# ### 2. Explore Environment
#
# <div style="text-align: center;">
#     <img src="./images/lunar_lander.gif" alt="Mountain Car Environment" width="50%">
# </div>
#
# #### Discreate Action Space
#
# There are four discrete actions available:
#
# - 0: do nothing
# - 1: fire left orientation engine
# - 2: fire main engine
# - 3: fire right orientation engine
#
# #### Continuous Observation Space
#
# The state is an 8-dimensional vector:
#
# - the coordinates of the lander in `x`
# - the coordinates of the lander in`y`,
# - linear velocities in `x`
# - linear velocities in `y`,
# - its angle,
# - its angular velocity, and
# - a booleans that represent whether `left` leg is in contact with the ground or not.
# - a booleans that represent whether `right` leg is in contact with the ground or not.

# %%
env = gym.make('LunarLander-v3', render_mode="rgb_array")

# %%
# Explore state (observation) space
print("State space:\n Continuous", env.observation_space.shape)
print(" - low:", env.observation_space.low)
print(" - high:", env.observation_space.high)

# Explore action space
print("Action space:\n", env.action_space)

print("-"*50)
# Generate some samples from the state space 
print("State space 10 samples:")
print(np.array([env.observation_space.sample() for i in range(10)]))

# Generate some samples from the action space
print("Action space 10 samples:")
print(np.array([env.action_space.sample() for i in range(10)]))
# Out:
# State space:
#  Continuous (8,)
#  - low: [ -2.5    -2.5   -10.    -10.     -6.283 -10.     -0.     -0.   ]
#  - high: [ 2.5    2.5   10.    10.     6.283 10.     1.     1.   ]
# Action space:
#  Discrete(4)
# --------------------------------------------------
# State space 10 samples:
# [[-1.426  1.536 -5.439  3.948  2.656 -8.077  0.873  0.482]
#  [-1.208  2.214 -1.127  2.101  4.709  4.982  0.258  0.375]
#  [ 0.471  0.342  4.681  1.171  1.697 -5.845  0.402  0.832]
#  [ 0.166  0.439 -1.478  3.563 -3.784 -4.595  0.971  0.33 ]
#  [ 0.561  2.474 -5.035 -7.065 -2.117  0.887  0.363  0.412]
#  [ 0.573  1.99   0.188  8.747  1.603 -0.64   0.021  0.871]
#  [-1.57  -0.808 -2.643 -5.325 -4.049  3.893  0.23   0.791]
#  [-0.997  2.136 -6.476 -0.754  6.065 -0.396  0.302  0.01 ]
#  [-1.593 -0.456  4.403  0.509 -0.756  1.364  0.652  0.679]
#  [ 0.441  0.862  8.749  2.344  3.8   -1.072  0.857  0.235]]
# Action space 10 samples:
# [2 2 1 0 1 3 3 1 0 3]

# %% [markdown]
# ### 3. Remove Replay Buffer
#
# #### Using Experience Replay Improve Training Stability
#
# <div style="text-align: center;">
#     <img src="./images/reply-buffer.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# When an agent interacts with the environment, the sequence of experience tuples can be highly correlated, which poses a risk for naive Q-learning algorithms. These algorithms, when learning sequentially from such correlated data, may lead to unstable updates, causing action values to oscillate or diverge.
#
# To address this, a replay buffer is introduced to store experience tuples $(S, A, R, S')$ collected during interactions with the environment. By using **experience replay**, small batches of tuples are randomly sampled from the buffer for training. This random sampling breaks harmful correlations, stabilizes learning, and allows the agent to:
# 1. Reuse individual experience tuples multiple times.
# 2. Recall rare events.
# 3. Make better overall use of past experiences.
#
# Experience replay thus improves the efficiency and stability of the learning process.
#
# <span style="color: red;">Update: </span> However, asynchronous methods eliminate the need for a replay buffer. In asynchronous one-step Q-learning and related methods, multiple agents (threads) interact with their own copies of the environment in parallel. This naturally introduces diversity into the data collected by each thread, breaking the correlation between consecutive updates. As a result:
#
# The updates from different threads act as a form of implicit decorrelation, reducing the risk of instability.
# The computational complexity of managing a replay buffer is avoided, making the algorithm simpler and more efficient.
# Thus, asynchronous mechanisms provide a built-in alternative to experience replay, achieving stability and efficiency without the need for a replay buffer.

# %% [markdown]
# ### 4. Define Q Network
#
# #### Using Neural Networks as Approximators for Q values
#
# <div style="text-align: center;">
#     <img src="./images/model-view.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# This image shows the transition from a **Traditional Q Table** to a **Parameterized Q Function** in reinforcement learning.
#
# The Q table (left) stores discrete Q-values $ Q(s_t, a_t) $ for each state-action pair but struggles with scalability in high-dimensional spaces. The parameterized Q function (right) replaces the table with a neural network $ Q(s_t, a_t; w) $, where $ w $ are the network's parameters.
#
# <div style="text-align: center;">
#     <img src="./images/model-arch.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# - Define a neural network architecture that maps states to action values $Q(s_t, a_t; w)$.

# %%
class QNetwork(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, hidden_size=64, seed=42):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.Q = nn.Sequential(
            nn.Linear(state_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, action_size)
        )

    def forward(self, state):
        """Build a network that maps state -> action values."""
        actions = self.Q(state)
        return actions


# test model
q_net = QNetwork(8, 4, 16, seed=42)
# fake input, by given batch size 4
states = torch.rand((4, 8))
# fake output size
print(q_net(states).shape)
# Out:
# torch.Size([4, 4])

# %% [markdown]
# ### 5. Define Agent
#
# ##### How to Learn in DQN
#
# <div style="text-align: center;">
#     <img src="./images/dqn-gradient-descent.png" alt="Mountain Car Environment" width="70%">
# </div>
#
# This image provides a visual summary of the core theory and update mechanism of **Deep Q-Network (DQN)**, showcasing the key formula derivations from **Q-Learning** to **DQN**, as well as how neural networks are used to approximate and update Q-values.
#
# ---
#
# **1. Core Idea Based on the Bellman Equation**
# - **Bellman Equation:**
#   $$
#   Q^*(s_t, a_t) = R_t + \gamma \max_a Q^*(s_{t+1}, a)
#   $$
#   - This states that the optimal Q-value for the current state-action pair equals the immediate reward $ R_t $ plus the discounted maximum Q-value of the next state.
#   - The core objective of DQN is to approximate this equation using a neural network.
#
# **2. Derivation from Q-Learning to DQN**
# - **Q-Learning Update Formula:**
#   $$
#   Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \alpha \left( R_t + \gamma \max_a Q(s_{t+1}, a) - Q(s_t, a_t) \right)
#   $$
#   - **TD Target:**
#     $$
#     R_t + \gamma \max_a Q(s_{t+1}, a)
#     $$
#     This represents the target Q-value for the current state, combining the immediate reward $ R_t $ and the maximum Q-value of the next state.
#   - **Current Value:**
#     $$
#     Q(s_t, a_t)
#     $$
#     This is the current estimated Q-value.
#   - **TD Error:**
#     $$
#     \delta_t = \left( R_t + \gamma \max_a Q(s_{t+1}, a) - Q(s_t, a_t) \right)
#     $$
#     This measures the difference between the target Q-value and the current Q-value.
#
# - **Neural Network Introduction:**
#   - To handle continuous state spaces, DQN replaces the traditional Q-table with a neural network $ Q(s, a; w) $, where $ w $ represents the network parameters.
#   - The goal is to optimize the network so that its output $ Q(s, a; w) $ approximates the true $ Q^*(s, a) $.
#
#
# **3. Loss Function and Gradient Update in DQN**
# - **Loss Function:**
#   $$
#   L(w) = \frac{1}{2} \left[ Q(s_t, a_t; w) - Q^*(s_t, a_t) \right]^2
#   $$
#   - Here, $ Q^*(s_t, a_t) $ is the target Q-value (TD Target) calculated using the Bellman equation.
#   - The loss function minimizes the squared error between the network's output $ Q(s_t, a_t; w) $ and the target Q-value $ Q^*(s_t, a_t) $.
#
# - **Gradient Calculation:**
#   $$
#   \nabla_w L(w) = \left( Q(s_t, a_t; w) - Q^*(s_t, a_t) \right) \nabla_w Q(s_t, a_t; w)
#   $$
#   - The gradient consists of two parts:
#     1. The error term: $ Q(s_t, a_t; w) - Q^*(s_t, a_t) $
#     2. The gradient of the network output: $ \nabla_w Q(s_t, a_t; w) $
#
# - **Weight Update:**
#   $$
#   w \leftarrow w - \alpha \nabla_w L(w)
#   $$
#   - Using gradient descent, the network parameters $ w $ are updated to reduce the loss function.
#
# - **Final DQN Update Formula:**
#   $$
#   L(w) = \frac{1}{2} \left[ Q(s_t, a_t; w) - (R_t + \gamma \max_a Q(s_{t+1}, a; w^-)) \right]^2
#   $$
#
#   $$
#   w' \leftarrow w + \alpha \left( R_t + \gamma \max_a Q(s_{t+1}, a; w^-) - Q(s_t, a_t; w) \right) \nabla_w Q(s_t, a_t; w)
#   $$
#   - Here, $ w^- $ represents the fixed target network parameters during the learning step, which are used to stabilize training.
#
#
# <span style="color: red;">Update: </span> **Asynchronous One Step Version**
#
# Like Paper [Asynchronous Methods for Deep Reinforcement Learning](https://arxiv.org/pdf/1602.01783) illustrated, we can implement Asynchronous One Step DQN like below with few modifications:
#
# <div style="text-align: center;">
#     <img src="./images/async-dqn-psedocode.png" width="40%">
# </div>

# %%
class Agent:
    """Interacts with and learns from the environment."""

    def __init__(
        self,
        state_size,
        action_size,
        Q_network,
        Q_target_network=None,
        optimizer=None,
        gamma=0.99,
        target_update_steps=1000,
        update_steps=5,
        seed=42,
        T=None,
        optimizer_lock=None
    ):
        """
        Initialize the agent.
        Args:
            state_size (int): Dimension of the state space.
            action_size (int): Dimension of the action space.
            Q_network (QNetwork): Main Q-Network.
            Q_target_network (QNetwork): Target Q-Network.
            optimizer (torch.optim.Optimizer): Optimizer for training.
            gamma (float): Discount factor.
            target_update_steps (int): Steps between target network updates.
            update_steps (int): Steps between gradient application.
            seed (int): Random seed for reproducibility.
            T (multiprocessing.Value): Global step counter shared across processes.
            optimizer_lock (multiprocessing.Lock): Lock for synchronizing optimizer updates.
        """
        self.state_size = state_size
        self.action_size = action_size
        self.Q = Q_network
        self.Q_target = Q_target_network
        self.optimizer = optimizer
        self.gamma = gamma
        self.target_update_steps = target_update_steps
        self.update_steps = update_steps  # Number of steps after which to apply gradients
        self.t_step = 0  # Time step counter for this thread
        self.T = T  # Shared global counter
        self.optimizer_lock = optimizer_lock
        self.seed = np.random.seed(seed)
        random.seed(seed)

        # Initialize accumulated gradients as None
        self.reset_gradients()
    
    def reset_gradients(self):
        """Reset accumulated gradients."""
        self.accumulated_grads = [torch.zeros_like(p) for p in self.Q.parameters()]
    
    def select_action(self, state, epsilon=0.0):
        """Selects an action using epsilon-greedy policy."""
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.Q.eval()
        with torch.no_grad():
            actions = self.Q(state)
        self.Q.train()

        # Epsilon-greedy action selection
        if random.random() > epsilon:
            return np.argmax(actions.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def step(self, state, action, reward, next_state, done):
        """Processes a step and learns from the experience."""
        # Convert experience to tensors
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        action = torch.tensor([[action]], dtype=torch.int64).to(device)
        reward = torch.tensor([[reward]], dtype=torch.float32).to(device)
        next_state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)
        done = torch.tensor([[done]], dtype=torch.float32).to(device)

        # Perform learning step
        loss = self.compute_loss((state, action, reward, next_state, done))
        
        # Backpropagate loss and accumulate gradients
        self.Q.zero_grad()
        loss.backward()

        # Accumulate gradients
        with torch.no_grad():
            for acc_grad, param in zip(self.accumulated_grads, self.Q.parameters()):
                acc_grad += param.grad.clone()

        # Increment step counters
        self.t_step += 1
        with self.T.get_lock():
            self.T.value += 1

        # Check if it's time to apply accumulated gradients
        if self.t_step % self.update_steps == 0 or done.item():
            self.apply_gradients()
            self.reset_gradients()
        
        # Update target network
        if self.T.value % self.target_update_steps == 0:
            self.hard_update()
        
    def compute_loss(self, experience):
        """Computes the loss for a single experience tuple."""
        state, action, reward, next_state, done = experience

        # Compute TD target using the target network
        with torch.no_grad():
            Q_targets_next = torch.max(self.Q_target(next_state), dim=-1, keepdim=True)[0]
            Q_targets = reward + (1 - done) * self.gamma * Q_targets_next

        # Compute expected Q values using the local network
        Q_expected = torch.gather(self.Q(state), dim=-1, index=action)

        # Compute loss (mean squared error)
        loss = F.mse_loss(Q_expected, Q_targets)
        return loss

    def apply_gradients(self):
        """Apply accumulated gradients to the shared network."""
        with self.optimizer_lock:
            for param, acc_grad in zip(self.Q.parameters(), self.accumulated_grads):
                param.grad = acc_grad  # Set the accumulated gradients

            # Perform optimizer step
            self.optimizer.step()
            # Zero the parameter gradients (in case they weren't zeroed)
            self.optimizer.zero_grad()
 
    def hard_update(self):
        """Hard update: θ_target = θ"""
        with self.optimizer_lock:
            self.Q_target.load_state_dict(self.Q.state_dict())

# %% [markdown]
# ### 7. Train the Agent with Async DQN

# %%
class SharedAdam(optim.Adam):
    """Shared Adam optimizer for multiprocessing"""

    def __init__(self, params, lr=5e-4):
        """
        Initialize the shared Adam optimizer.
        Args:
            params: Parameters to optimize.
            lr (float): Learning rate.
        """
        super(SharedAdam, self).__init__(params, lr=lr)
        for group in self.param_groups:
            for p in group['params']:
                # Initialize optimizer state
                state = self.state[p]
                state['step'] = torch.tensor(0)
                state['exp_avg'] = torch.zeros_like(p.data)
                state['exp_avg_sq'] = torch.zeros_like(p.data)
                # Share memory for multiprocessing
                state['exp_avg'].share_memory_()
                state['exp_avg_sq'].share_memory_()
                state['step'].share_memory_()

# %%
def worker_dqn(rank, Q, Q_target, optimizer, T, max_score, env_name, num_episodes=2000, max_t=1000, window=100, optimizer_lock=None):
    """
    Function executed by each worker process.
    Args:
        rank (int): Process rank.
        Q (QNetwork): Shared Q-network.
        Q_target (QNetwork): Shared target Q-network.
        optimizer (SharedAdam): Shared optimizer.
        T (multiprocessing.Value): Global step counter.
        max_score (multiprocessing.Value): Global maximum score.
        env_name (str): Environment name.
        num_episodes (int): Number of training episodes.
        max_t (int): Maximum steps per episode.
        window (int): Window size for calculating average scores.
        optimizer_lock (multiprocessing.Lock): Lock for synchronizing optimizer updates.
    """
    # Create an environment instance for each worker
    env = gym.make(env_name)
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # Initialize the agent with shared networks and optimizer
    agent = Agent(
        state_size=state_size,
        action_size=action_size,
        Q_network=Q,
        Q_target_network=Q_target,
        optimizer=optimizer,
        gamma=0.995,
        target_update_steps=50,
        update_steps=10,
        seed=42 + rank,
        T=T,
        optimizer_lock=optimizer_lock
    )
    
    epsilon = 1.0
    eps_min = 0.01
    eps_decay = 0.999
    
    scores_window = deque(maxlen=window)

    for i_episode in range(1, num_episodes + 1):
        with max_score.get_lock():
            if max_score.value >= 200.0:
                break
            
        state, _ = env.reset()
        total_reward = 0
        agent.t_step = 0
        agent.reset_gradients()
        done = False

        for t in range(max_t):
            action = agent.select_action(state, epsilon)
            next_state, reward, done, _, info = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            if done:
                break
        
        # Decay epsilon
        epsilon = max(eps_min, eps_decay * epsilon)
        
        scores_window.append(total_reward)
        mean_score = np.mean(scores_window)

        if i_episode % 10 == 0:
            print(f"Process {rank}, Episode {i_episode}, Total Reward: {total_reward:.2f}, Average Score: {mean_score:.2f}")

        if len(scores_window) >= window and mean_score >= 200.0:
            with max_score.get_lock():
                max_score.value = mean_score
                if rank == 0:
                    print(f"\nEnvironment solved in {i_episode:d} episodes!\tAverage Score: {mean_score:.2f}")
                    torch.save(agent.Q.state_dict(), "checkpoint.pth")
            break

    env.close()

# %% [markdown]
# <span style="color: red;">Update: </span> Below code in this [script](./asynchronous_one_step_dqn_lunarlander.py)

# %%
# %run asynchronous_one_step_dqn_lunarlander.py
# Out:
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Training on: cpu
# Process 0, Episode 10, Total Reward: -62.89, Average Score: -164.86
# Process 4, Episode 10, Total Reward: -46.94, Average Score: -184.44
# Process 3, Episode 10, Total Reward: -72.08, Average Score: -157.75
# Process 1, Episode 10, Total Reward: -191.59, Average Score: -215.08
# Process 2, Episode 10, Total Reward: -2.08, Average Score: -174.58
# Process 6, Episode 10, Total Reward: -113.71, Average Score: -168.11
# Process 7, Episode 10, Total Reward: -223.21, Average Score: -180.03
# Process 5, Episode 10, Total Reward: -195.87, Average Score: -158.26
# Process 0, Episode 20, Total Reward: -122.02, Average Score: -171.95
# Process 3, Episode 20, Total Reward: -126.66, Average Score: -166.19
# Process 4, Episode 20, Total Reward: -126.06, Average Score: -163.44
# Process 6, Episode 20, Total Reward: -328.07, Average Score: -195.48
# Process 2, Episode 20, Total Reward: -272.42, Average Score: -166.24
# Process 7, Episode 20, Total Reward: -367.36, Average Score: -191.17
# Process 1, Episode 20, Total Reward: -215.45, Average Score: -220.82
# Process 5, Episode 20, Total Reward: -147.16, Average Score: -197.72
# Process 0, Episode 30, Total Reward: -334.62, Average Score: -171.09
# Process 2, Episode 30, Total Reward: -168.76, Average Score: -167.45
# Process 4, Episode 30, Total Reward: -206.11, Average Score: -158.94
# Process 3, Episode 30, Total Reward: -79.21, Average Score: -163.78
# Process 6, Episode 30, Total Reward: 34.25, Average Score: -175.19
# Process 7, Episode 30, Total Reward: -102.88, Average Score: -182.97
# Process 1, Episode 30, Total Reward: -116.42, Average Score: -204.38
# Process 5, Episode 30, Total Reward: -171.92, Average Score: -183.60
# Process 0, Episode 40, Total Reward: -112.22, Average Score: -163.91
# Process 4, Episode 40, Total Reward: -216.72, Average Score: -158.33
# Process 3, Episode 40, Total Reward: -302.50, Average Score: -163.06
# Process 6, Episode 40, Total Reward: -132.43, Average Score: -167.58
# Process 2, Episode 40, Total Reward: -256.70, Average Score: -161.36
# Process 7, Episode 40, Total Reward: -412.94, Average Score: -186.06
# Process 1, Episode 40, Total Reward: -220.14, Average Score: -205.11
# Process 5, Episode 40, Total Reward: -21.33, Average Score: -186.30
# Process 0, Episode 50, Total Reward: -115.23, Average Score: -158.91
# Process 4, Episode 50, Total Reward: -111.30, Average Score: -162.70
# Process 3, Episode 50, Total Reward: -107.38, Average Score: -160.62
# Process 6, Episode 50, Total Reward: -64.23, Average Score: -176.18
# Process 2, Episode 50, Total Reward: -110.70, Average Score: -166.24
# Process 1, Episode 50, Total Reward: -142.59, Average Score: -200.13
# Process 7, Episode 50, Total Reward: -90.07, Average Score: -186.68
# Process 5, Episode 50, Total Reward: -38.02, Average Score: -174.20
# Process 0, Episode 60, Total Reward: -104.48, Average Score: -159.06
# Process 4, Episode 60, Total Reward: -79.05, Average Score: -165.52
# Process 2, Episode 60, Total Reward: -92.25, Average Score: -167.08
# Process 1, Episode 60, Total Reward: -188.94, Average Score: -192.64
# Process 6, Episode 60, Total Reward: -132.89, Average Score: -167.57
# Process 3, Episode 60, Total Reward: -316.13, Average Score: -164.64
# Process 7, Episode 60, Total Reward: -269.14, Average Score: -185.21
# Process 5, Episode 60, Total Reward: -218.10, Average Score: -171.96
# Process 0, Episode 70, Total Reward: -349.59, Average Score: -160.34
# Process 4, Episode 70, Total Reward: -112.70, Average Score: -165.32
# Process 2, Episode 70, Total Reward: -151.50, Average Score: -165.98
# Process 1, Episode 70, Total Reward: -127.99, Average Score: -186.15
# Process 6, Episode 70, Total Reward: -80.14, Average Score: -170.07
# Process 7, Episode 70, Total Reward: -124.42, Average Score: -176.51
# Process 3, Episode 70, Total Reward: -227.77, Average Score: -157.64
# Process 5, Episode 70, Total Reward: -243.72, Average Score: -178.00
# Process 0, Episode 80, Total Reward: -72.60, Average Score: -161.36
# Process 4, Episode 80, Total Reward: -131.52, Average Score: -166.95
# Process 2, Episode 80, Total Reward: -89.12, Average Score: -162.78
# Process 3, Episode 80, Total Reward: -107.93, Average Score: -155.01
# Process 7, Episode 80, Total Reward: -99.55, Average Score: -171.49
# Process 6, Episode 80, Total Reward: -118.53, Average Score: -168.12
# Process 5, Episode 80, Total Reward: -120.09, Average Score: -174.79
# Process 0, Episode 90, Total Reward: -196.20, Average Score: -163.75
# Process 4, Episode 90, Total Reward: -77.93, Average Score: -164.59
# Process 3, Episode 90, Total Reward: -78.67, Average Score: -150.57
# Process 1, Episode 80, Total Reward: 76.11, Average Score: -178.78
# Process 6, Episode 90, Total Reward: -160.85, Average Score: -163.45
# Process 2, Episode 90, Total Reward: -287.80, Average Score: -169.62
# Process 7, Episode 90, Total Reward: -312.66, Average Score: -172.79
# Process 5, Episode 90, Total Reward: -125.93, Average Score: -172.27
# Process 0, Episode 100, Total Reward: -62.52, Average Score: -168.27
# Process 4, Episode 100, Total Reward: -105.34, Average Score: -158.52
# Process 3, Episode 100, Total Reward: -68.75, Average Score: -146.50
# Process 1, Episode 90, Total Reward: -255.73, Average Score: -174.15
# Process 6, Episode 100, Total Reward: -80.55, Average Score: -161.68
# Process 2, Episode 100, Total Reward: -102.25, Average Score: -167.24
# Process 7, Episode 100, Total Reward: -103.30, Average Score: -174.25
# Process 5, Episode 100, Total Reward: -82.58, Average Score: -166.34
# Process 0, Episode 110, Total Reward: -307.87, Average Score: -164.21
# Process 4, Episode 110, Total Reward: -359.74, Average Score: -156.14
# Process 3, Episode 110, Total Reward: -312.93, Average Score: -147.71
# Process 1, Episode 100, Total Reward: -242.05, Average Score: -172.75
# Process 6, Episode 110, Total Reward: -86.05, Average Score: -156.71
# Process 2, Episode 110, Total Reward: -140.98, Average Score: -163.22
# Process 7, Episode 110, Total Reward: -243.90, Average Score: -168.75
# Process 5, Episode 110, Total Reward: -200.02, Average Score: -166.49
# Process 0, Episode 120, Total Reward: -153.88, Average Score: -161.69
# Process 4, Episode 120, Total Reward: -63.32, Average Score: -155.93
# Process 3, Episode 120, Total Reward: -15.03, Average Score: -140.48
# Process 6, Episode 120, Total Reward: -161.63, Average Score: -144.90
# Process 2, Episode 120, Total Reward: -180.16, Average Score: -158.79
# Process 1, Episode 110, Total Reward: -153.91, Average Score: -164.42
# Process 5, Episode 120, Total Reward: -101.82, Average Score: -158.52
# Process 0, Episode 130, Total Reward: -122.12, Average Score: -155.95
# Process 6, Episode 130, Total Reward: -158.13, Average Score: -146.37
# Process 4, Episode 130, Total Reward: -175.95, Average Score: -159.17
# Process 3, Episode 130, Total Reward: -76.54, Average Score: -139.86
# Process 2, Episode 130, Total Reward: -132.86, Average Score: -154.03
# Process 1, Episode 120, Total Reward: -76.49, Average Score: -157.01
# Process 7, Episode 120, Total Reward: -238.14, Average Score: -163.15
# Process 5, Episode 130, Total Reward: -99.41, Average Score: -158.36
# Process 4, Episode 140, Total Reward: -269.06, Average Score: -155.17
# Process 6, Episode 140, Total Reward: -159.03, Average Score: -143.14
# Process 3, Episode 140, Total Reward: -73.41, Average Score: -139.78
# Process 1, Episode 130, Total Reward: -164.87, Average Score: -150.92
# Process 2, Episode 140, Total Reward: -96.88, Average Score: -156.98
# Process 7, Episode 130, Total Reward: -234.77, Average Score: -159.05
# Process 5, Episode 140, Total Reward: 46.72, Average Score: -146.92
# Process 0, Episode 140, Total Reward: -168.99, Average Score: -156.42
# Process 6, Episode 150, Total Reward: -52.11, Average Score: -132.96
# Process 4, Episode 150, Total Reward: -125.98, Average Score: -151.09
# Process 3, Episode 150, Total Reward: -123.02, Average Score: -136.82
# Process 2, Episode 150, Total Reward: -77.08, Average Score: -152.70
# Process 1, Episode 140, Total Reward: -93.81, Average Score: -145.12
# Process 5, Episode 150, Total Reward: 23.43, Average Score: -142.99
# Process 0, Episode 150, Total Reward: -127.92, Average Score: -159.35
# Process 7, Episode 140, Total Reward: -131.73, Average Score: -151.36
# Process 6, Episode 160, Total Reward: -256.31, Average Score: -132.51
# Process 4, Episode 160, Total Reward: -114.96, Average Score: -148.99
# Process 2, Episode 160, Total Reward: -152.17, Average Score: -149.02
# Process 3, Episode 160, Total Reward: -387.33, Average Score: -132.23
# Process 1, Episode 150, Total Reward: -149.33, Average Score: -144.31
# Process 5, Episode 160, Total Reward: -165.14, Average Score: -136.27
# Process 7, Episode 150, Total Reward: -214.11, Average Score: -149.22
# Process 6, Episode 170, Total Reward: -83.81, Average Score: -124.37
# Process 4, Episode 170, Total Reward: -81.78, Average Score: -145.67
# Process 2, Episode 170, Total Reward: -117.81, Average Score: -145.25
# Process 3, Episode 170, Total Reward: -176.19, Average Score: -133.84
# Process 1, Episode 160, Total Reward: -97.12, Average Score: -142.29
# Process 0, Episode 160, Total Reward: -69.77, Average Score: -155.93
# Process 5, Episode 170, Total Reward: -36.63, Average Score: -123.26
# Process 4, Episode 180, Total Reward: -76.74, Average Score: -137.19
# Process 6, Episode 180, Total Reward: -79.93, Average Score: -119.62
# Process 2, Episode 180, Total Reward: -123.52, Average Score: -138.25
# Process 1, Episode 170, Total Reward: -121.66, Average Score: -139.54
# Process 3, Episode 180, Total Reward: 7.85, Average Score: -132.45
# Process 0, Episode 170, Total Reward: -94.43, Average Score: -154.86
# Process 5, Episode 180, Total Reward: -169.79, Average Score: -118.21
# Process 7, Episode 160, Total Reward: -160.13, Average Score: -141.45
# Process 6, Episode 190, Total Reward: -31.46, Average Score: -117.07
# Process 4, Episode 190, Total Reward: -108.28, Average Score: -132.30
# Process 2, Episode 190, Total Reward: -106.79, Average Score: -126.76
# Process 1, Episode 180, Total Reward: -87.78, Average Score: -137.63
# Process 3, Episode 190, Total Reward: -12.18, Average Score: -135.88
# Process 0, Episode 180, Total Reward: -141.04, Average Score: -153.63
# Process 5, Episode 190, Total Reward: -136.21, Average Score: -112.42
# Process 7, Episode 170, Total Reward: -102.75, Average Score: -141.03
# Process 6, Episode 200, Total Reward: -104.15, Average Score: -112.52
# Process 4, Episode 200, Total Reward: -78.40, Average Score: -135.71
# Process 2, Episode 200, Total Reward: -124.95, Average Score: -121.82
# Process 1, Episode 190, Total Reward: -104.60, Average Score: -136.58
# Process 0, Episode 190, Total Reward: -59.06, Average Score: -144.70
# Process 3, Episode 200, Total Reward: -137.56, Average Score: -133.93
# Process 5, Episode 200, Total Reward: -192.03, Average Score: -115.32
# Process 7, Episode 180, Total Reward: -138.75, Average Score: -135.60
# Process 6, Episode 210, Total Reward: -133.03, Average Score: -117.44
# Process 2, Episode 210, Total Reward: -93.33, Average Score: -121.91
# Process 4, Episode 210, Total Reward: -98.64, Average Score: -134.01
# Process 0, Episode 200, Total Reward: -65.51, Average Score: -136.73
# Process 3, Episode 210, Total Reward: -288.23, Average Score: -131.21
# Process 7, Episode 190, Total Reward: -78.52, Average Score: -128.16
# Process 5, Episode 210, Total Reward: -59.64, Average Score: -109.12
# Process 2, Episode 220, Total Reward: -23.66, Average Score: -118.26
# Process 6, Episode 220, Total Reward: -132.75, Average Score: -116.18
# Process 4, Episode 220, Total Reward: -116.63, Average Score: -131.81
# Process 1, Episode 200, Total Reward: -91.28, Average Score: -129.06
# Process 0, Episode 210, Total Reward: -81.31, Average Score: -133.50
# Process 3, Episode 220, Total Reward: -95.76, Average Score: -130.29
# Process 6, Episode 230, Total Reward: -101.51, Average Score: -109.58
# Process 7, Episode 200, Total Reward: -110.56, Average Score: -120.81
# Process 2, Episode 230, Total Reward: 7.45, Average Score: -116.38
# Process 1, Episode 210, Total Reward: -95.42, Average Score: -124.43
# Process 0, Episode 220, Total Reward: -65.76, Average Score: -130.99
# Process 3, Episode 230, Total Reward: -19.95, Average Score: -124.41
# Process 6, Episode 240, Total Reward: -55.79, Average Score: -108.04
# Process 7, Episode 210, Total Reward: -83.64, Average Score: -119.77
# Process 5, Episode 220, Total Reward: -145.36, Average Score: -103.46
# Process 2, Episode 240, Total Reward: -198.96, Average Score: -109.22
# Process 1, Episode 220, Total Reward: -142.91, Average Score: -120.20
# Process 4, Episode 230, Total Reward: -82.89, Average Score: -122.91
# Process 0, Episode 230, Total Reward: -292.60, Average Score: -133.06
# Process 3, Episode 240, Total Reward: -142.03, Average Score: -119.54
# Process 6, Episode 250, Total Reward: -149.67, Average Score: -106.92
# Process 7, Episode 220, Total Reward: -61.12, Average Score: -118.17
# Process 2, Episode 250, Total Reward: -143.42, Average Score: -104.46
# Process 5, Episode 230, Total Reward: -228.05, Average Score: -100.96
# Process 4, Episode 240, Total Reward: -79.26, Average Score: -120.12
# Process 1, Episode 230, Total Reward: -125.99, Average Score: -121.85
# Process 0, Episode 240, Total Reward: -132.37, Average Score: -130.50
# Process 3, Episode 250, Total Reward: -76.32, Average Score: -117.49
# Process 6, Episode 260, Total Reward: -81.07, Average Score: -108.40
# Process 2, Episode 260, Total Reward: -50.70, Average Score: -98.78
# Process 7, Episode 230, Total Reward: -177.17, Average Score: -116.50
# Process 1, Episode 240, Total Reward: -75.60, Average Score: -117.35
# Process 4, Episode 250, Total Reward: -228.68, Average Score: -118.04
# Process 0, Episode 250, Total Reward: -76.37, Average Score: -127.71
# Process 3, Episode 260, Total Reward: -97.46, Average Score: -114.92
# Process 6, Episode 270, Total Reward: -132.57, Average Score: -111.59
# Process 5, Episode 240, Total Reward: 59.55, Average Score: -101.44
# Process 2, Episode 270, Total Reward: -170.35, Average Score: -100.73
# Process 7, Episode 240, Total Reward: -62.86, Average Score: -115.00
# Process 4, Episode 260, Total Reward: -133.53, Average Score: -112.86
# Process 1, Episode 250, Total Reward: -86.92, Average Score: -110.35
# Process 0, Episode 260, Total Reward: -100.81, Average Score: -126.82
# Process 3, Episode 270, Total Reward: -97.49, Average Score: -112.76
# Process 5, Episode 250, Total Reward: -104.10, Average Score: -103.77
# Process 2, Episode 280, Total Reward: -83.90, Average Score: -103.59
# Process 7, Episode 250, Total Reward: -60.17, Average Score: -107.33
# Process 6, Episode 280, Total Reward: -121.43, Average Score: -111.50
# Process 1, Episode 260, Total Reward: -85.93, Average Score: -108.08
# Process 4, Episode 270, Total Reward: -386.05, Average Score: -115.46
# Process 0, Episode 270, Total Reward: -67.95, Average Score: -121.83
# Process 3, Episode 280, Total Reward: -102.04, Average Score: -109.18
# Process 2, Episode 290, Total Reward: -97.98, Average Score: -101.62
# Process 7, Episode 260, Total Reward: -74.07, Average Score: -107.55
# Process 5, Episode 260, Total Reward: -50.62, Average Score: -104.39
# Process 6, Episode 290, Total Reward: -103.57, Average Score: -110.97
# Process 4, Episode 280, Total Reward: -98.37, Average Score: -116.33
# Process 1, Episode 270, Total Reward: -81.60, Average Score: -107.95
# Process 0, Episode 280, Total Reward: -96.66, Average Score: -113.33
# Process 3, Episode 290, Total Reward: -141.49, Average Score: -104.76
# Process 7, Episode 270, Total Reward: -74.93, Average Score: -101.64
# Process 4, Episode 290, Total Reward: -111.68, Average Score: -115.24
# Process 2, Episode 300, Total Reward: -51.12, Average Score: -99.63
# Process 6, Episode 300, Total Reward: -112.51, Average Score: -109.37
# Process 5, Episode 270, Total Reward: -130.59, Average Score: -103.35
# Process 1, Episode 280, Total Reward: -80.66, Average Score: -107.63
# Process 0, Episode 290, Total Reward: -138.88, Average Score: -112.26
# Process 3, Episode 300, Total Reward: -151.68, Average Score: -107.36
# Process 7, Episode 280, Total Reward: -75.55, Average Score: -103.52
# Process 4, Episode 300, Total Reward: -203.36, Average Score: -112.67
# Process 2, Episode 310, Total Reward: -68.80, Average Score: -96.19
# Process 6, Episode 310, Total Reward: -59.92, Average Score: -101.81
# Process 5, Episode 280, Total Reward: -110.40, Average Score: -101.37
# Process 1, Episode 290, Total Reward: -145.00, Average Score: -104.66
# Process 0, Episode 300, Total Reward: -122.53, Average Score: -106.24
# Process 3, Episode 310, Total Reward: -83.79, Average Score: -103.20
# Process 7, Episode 290, Total Reward: -63.18, Average Score: -103.68
# Process 2, Episode 320, Total Reward: -135.01, Average Score: -98.57
# Process 4, Episode 310, Total Reward: -5.63, Average Score: -110.26
# Process 1, Episode 300, Total Reward: -115.88, Average Score: -107.03
# Process 5, Episode 290, Total Reward: -91.54, Average Score: -104.02
# Process 6, Episode 320, Total Reward: -78.16, Average Score: -101.40
# Process 0, Episode 310, Total Reward: -103.11, Average Score: -105.63
# Process 3, Episode 320, Total Reward: -117.94, Average Score: -103.73
# Process 7, Episode 300, Total Reward: -84.08, Average Score: -101.08
# Process 5, Episode 300, Total Reward: -43.92, Average Score: -96.14
# Process 1, Episode 310, Total Reward: -85.20, Average Score: -107.10
# Process 4, Episode 320, Total Reward: -15.62, Average Score: -107.78
# Process 6, Episode 330, Total Reward: -61.97, Average Score: -102.33
# Process 0, Episode 320, Total Reward: -55.29, Average Score: -101.86
# Process 3, Episode 330, Total Reward: -93.24, Average Score: -102.52
# Process 2, Episode 330, Total Reward: 52.37, Average Score: -94.23
# Process 7, Episode 310, Total Reward: -50.61, Average Score: -97.62
# Process 4, Episode 330, Total Reward: -117.72, Average Score: -110.74
# Process 5, Episode 310, Total Reward: -147.04, Average Score: -94.12
# Process 1, Episode 320, Total Reward: -132.95, Average Score: -107.25
# Process 6, Episode 340, Total Reward: -112.81, Average Score: -99.87
# Process 0, Episode 330, Total Reward: -112.34, Average Score: -96.90
# Process 3, Episode 340, Total Reward: -62.77, Average Score: -99.67
# Process 2, Episode 340, Total Reward: -85.87, Average Score: -92.33
# Process 7, Episode 320, Total Reward: -67.10, Average Score: -91.07
# Process 5, Episode 320, Total Reward: -102.90, Average Score: -93.18
# Process 4, Episode 340, Total Reward: 17.94, Average Score: -108.50
# Process 1, Episode 330, Total Reward: -36.41, Average Score: -104.55
# Process 6, Episode 350, Total Reward: -157.95, Average Score: -98.46
# Process 0, Episode 340, Total Reward: -133.59, Average Score: -93.12
# Process 2, Episode 350, Total Reward: -52.47, Average Score: -89.10
# Process 3, Episode 350, Total Reward: -124.31, Average Score: -98.89
# Process 7, Episode 330, Total Reward: -177.59, Average Score: -88.30
# Process 5, Episode 330, Total Reward: -88.33, Average Score: -90.41
# Process 4, Episode 350, Total Reward: -31.68, Average Score: -102.26
# Process 1, Episode 340, Total Reward: -92.44, Average Score: -104.22
# Process 6, Episode 360, Total Reward: -77.59, Average Score: -92.63
# Process 0, Episode 350, Total Reward: -101.55, Average Score: -87.79
# Process 2, Episode 360, Total Reward: -38.93, Average Score: -90.03
# Process 3, Episode 360, Total Reward: -67.78, Average Score: -92.08
# Process 7, Episode 340, Total Reward: -78.68, Average Score: -87.21
# Process 6, Episode 370, Total Reward: -117.47, Average Score: -88.93
# Process 1, Episode 350, Total Reward: -74.56, Average Score: -102.22
# Process 5, Episode 340, Total Reward: -102.96, Average Score: -87.96
# Process 4, Episode 360, Total Reward: -84.86, Average Score: -101.54
# Process 0, Episode 360, Total Reward: -84.93, Average Score: -84.83
# Process 3, Episode 370, Total Reward: -30.37, Average Score: -90.01
# Process 2, Episode 370, Total Reward: -75.55, Average Score: -85.70
# Process 7, Episode 350, Total Reward: -52.06, Average Score: -86.68
# Process 4, Episode 370, Total Reward: -52.83, Average Score: -93.15
# Process 6, Episode 380, Total Reward: -86.54, Average Score: -86.58
# Process 5, Episode 350, Total Reward: -89.28, Average Score: -87.62
# Process 3, Episode 380, Total Reward: -120.27, Average Score: -87.94
# Process 0, Episode 370, Total Reward: -45.62, Average Score: -80.81
# Process 2, Episode 380, Total Reward: -47.79, Average Score: -81.91
# Process 1, Episode 360, Total Reward: -94.33, Average Score: -98.43
# Process 7, Episode 360, Total Reward: -59.42, Average Score: -84.53
# Process 4, Episode 380, Total Reward: -71.75, Average Score: -88.74
# Process 6, Episode 390, Total Reward: -62.83, Average Score: -86.18
# Process 5, Episode 360, Total Reward: -64.76, Average Score: -85.43
# Process 3, Episode 390, Total Reward: -81.72, Average Score: -85.84
# Process 0, Episode 380, Total Reward: -71.92, Average Score: -80.51
# Process 1, Episode 370, Total Reward: -36.52, Average Score: -96.19
# Process 2, Episode 390, Total Reward: -46.77, Average Score: -78.89
# Process 4, Episode 390, Total Reward: -106.31, Average Score: -87.61
# Process 7, Episode 370, Total Reward: -101.44, Average Score: -85.08
# Process 6, Episode 400, Total Reward: -4.85, Average Score: -86.39
# Process 5, Episode 370, Total Reward: -73.59, Average Score: -86.05
# Process 3, Episode 400, Total Reward: -109.22, Average Score: -80.99
# Process 0, Episode 390, Total Reward: -29.40, Average Score: -78.00
# Process 1, Episode 380, Total Reward: -37.36, Average Score: -91.96
# Process 4, Episode 400, Total Reward: -84.72, Average Score: -81.60
# Process 5, Episode 380, Total Reward: -87.93, Average Score: -84.47
# Process 2, Episode 400, Total Reward: -85.09, Average Score: -80.17
# Process 6, Episode 410, Total Reward: -38.73, Average Score: -85.24
# Process 3, Episode 410, Total Reward: -55.59, Average Score: -80.43
# Process 1, Episode 390, Total Reward: -81.84, Average Score: -90.31
# Process 0, Episode 400, Total Reward: -48.45, Average Score: -78.49
# Process 7, Episode 380, Total Reward: -108.76, Average Score: -80.78
# Process 2, Episode 410, Total Reward: -90.28, Average Score: -76.30
# Process 6, Episode 420, Total Reward: -45.73, Average Score: -84.77
# Process 5, Episode 390, Total Reward: -67.23, Average Score: -78.48
# Process 3, Episode 420, Total Reward: -38.11, Average Score: -77.43
# Process 0, Episode 410, Total Reward: -94.72, Average Score: -77.43
# Process 1, Episode 400, Total Reward: -222.60, Average Score: -88.01
# Process 4, Episode 410, Total Reward: -87.14, Average Score: -75.49
# Process 7, Episode 390, Total Reward: -110.32, Average Score: -78.20
# Process 2, Episode 420, Total Reward: -75.78, Average Score: -75.90
# Process 5, Episode 400, Total Reward: -38.87, Average Score: -82.06
# Process 6, Episode 430, Total Reward: -90.28, Average Score: -81.72
# Process 4, Episode 420, Total Reward: -70.89, Average Score: -73.90
# Process 1, Episode 410, Total Reward: -30.60, Average Score: -89.51
# Process 7, Episode 400, Total Reward: -83.49, Average Score: -75.03
# Process 2, Episode 430, Total Reward: -53.27, Average Score: -75.89
# Process 3, Episode 430, Total Reward: -92.77, Average Score: -76.26
# Process 6, Episode 440, Total Reward: -51.66, Average Score: -81.32
# Process 5, Episode 410, Total Reward: -58.56, Average Score: -81.01
# Process 0, Episode 420, Total Reward: 23.44, Average Score: -73.58
# Process 4, Episode 430, Total Reward: -27.78, Average Score: -69.81
# Process 7, Episode 410, Total Reward: -30.40, Average Score: -73.53
# Process 1, Episode 420, Total Reward: 17.54, Average Score: -82.79
# Process 2, Episode 440, Total Reward: -67.28, Average Score: -74.99
# Process 3, Episode 440, Total Reward: 4.07, Average Score: -75.02
# Process 6, Episode 450, Total Reward: 12.03, Average Score: -79.50
# Process 5, Episode 420, Total Reward: -39.33, Average Score: -79.17
# Process 0, Episode 430, Total Reward: -28.39, Average Score: -72.11
# Process 4, Episode 440, Total Reward: -27.38, Average Score: -69.67
# Process 7, Episode 420, Total Reward: -52.17, Average Score: -75.34
# Process 1, Episode 430, Total Reward: -13.08, Average Score: -77.24
# Process 3, Episode 450, Total Reward: -78.60, Average Score: -71.59
# Process 2, Episode 450, Total Reward: -15.08, Average Score: -73.81
# Process 5, Episode 430, Total Reward: -45.16, Average Score: -76.47
# Process 6, Episode 460, Total Reward: -78.15, Average Score: -76.79
# Process 0, Episode 440, Total Reward: -89.61, Average Score: -71.13
# Process 4, Episode 450, Total Reward: -91.63, Average Score: -70.81
# Process 1, Episode 440, Total Reward: -95.42, Average Score: -75.15
# Process 7, Episode 430, Total Reward: -92.22, Average Score: -74.62
# Process 3, Episode 460, Total Reward: -2.48, Average Score: -75.29
# Process 2, Episode 460, Total Reward: 8.16, Average Score: -71.18
# Process 5, Episode 440, Total Reward: -65.29, Average Score: -76.00
# Process 6, Episode 470, Total Reward: -68.43, Average Score: -73.98
# Process 0, Episode 450, Total Reward: -47.88, Average Score: -69.94
# Process 4, Episode 460, Total Reward: -61.45, Average Score: -66.98
# Process 7, Episode 440, Total Reward: -73.27, Average Score: -72.91
# Process 1, Episode 450, Total Reward: -3.48, Average Score: -72.86
# Process 2, Episode 470, Total Reward: -36.17, Average Score: -67.50
# Process 3, Episode 470, Total Reward: 7.53, Average Score: -71.28
# Process 6, Episode 480, Total Reward: -97.51, Average Score: -72.60
# Process 5, Episode 450, Total Reward: -102.07, Average Score: -72.13
# Process 0, Episode 460, Total Reward: -19.02, Average Score: -67.44
# Process 7, Episode 450, Total Reward: -130.37, Average Score: -71.41
# Process 3, Episode 480, Total Reward: -36.32, Average Score: -71.01
# Process 6, Episode 490, Total Reward: -83.28, Average Score: -71.30
# Process 1, Episode 460, Total Reward: -107.07, Average Score: -71.49
# Process 2, Episode 480, Total Reward: -78.59, Average Score: -68.88
# Process 4, Episode 470, Total Reward: -280.25, Average Score: -70.01
# Process 3, Episode 490, Total Reward: -70.23, Average Score: -71.40
# Process 7, Episode 460, Total Reward: -54.71, Average Score: -71.38
# Process 0, Episode 470, Total Reward: -90.99, Average Score: -66.41
# Process 5, Episode 460, Total Reward: -60.01, Average Score: -71.93
# Process 6, Episode 500, Total Reward: -39.41, Average Score: -69.17
# Process 1, Episode 470, Total Reward: -127.84, Average Score: -67.67
# Process 3, Episode 500, Total Reward: -25.68, Average Score: -70.29
# Process 0, Episode 480, Total Reward: -21.79, Average Score: -68.41
# Process 5, Episode 470, Total Reward: -77.56, Average Score: -72.84
# Process 6, Episode 510, Total Reward: -6.67, Average Score: -66.25
# Process 4, Episode 480, Total Reward: -155.94, Average Score: -71.13
# Process 1, Episode 480, Total Reward: -156.34, Average Score: -70.38
# Process 2, Episode 490, Total Reward: -105.09, Average Score: -69.56
# Process 3, Episode 510, Total Reward: -62.24, Average Score: -69.37
# Process 0, Episode 490, Total Reward: -58.45, Average Score: -67.97
# Process 5, Episode 480, Total Reward: -59.28, Average Score: -70.92
# Process 7, Episode 470, Total Reward: -61.01, Average Score: -71.24
# Process 4, Episode 490, Total Reward: -35.39, Average Score: -71.07
# Process 1, Episode 490, Total Reward: -37.69, Average Score: -67.61
# Process 2, Episode 500, Total Reward: -111.20, Average Score: -66.51
# Process 6, Episode 520, Total Reward: -92.68, Average Score: -66.79
# Process 0, Episode 500, Total Reward: -74.14, Average Score: -67.67
# Process 4, Episode 500, Total Reward: -6.61, Average Score: -73.30
# Process 7, Episode 480, Total Reward: -129.50, Average Score: -72.94
# Process 3, Episode 520, Total Reward: -286.01, Average Score: -69.17
# Process 2, Episode 510, Total Reward: -53.51, Average Score: -66.69
# Process 5, Episode 490, Total Reward: -91.27, Average Score: -72.41
# Process 1, Episode 500, Total Reward: -26.89, Average Score: -66.55
# Process 6, Episode 530, Total Reward: -70.01, Average Score: -67.11
# Process 0, Episode 510, Total Reward: -47.99, Average Score: -65.43
# Process 4, Episode 510, Total Reward: 0.58, Average Score: -74.57
# Process 7, Episode 490, Total Reward: -79.05, Average Score: -71.52
# Process 2, Episode 520, Total Reward: -140.10, Average Score: -64.85
# Process 5, Episode 500, Total Reward: -8.23, Average Score: -70.17
# Process 3, Episode 530, Total Reward: -91.60, Average Score: -70.16
# Process 0, Episode 520, Total Reward: -128.10, Average Score: -66.60
# Process 4, Episode 520, Total Reward: -54.18, Average Score: -72.79
# Process 1, Episode 510, Total Reward: -102.11, Average Score: -69.67
# Process 5, Episode 510, Total Reward: -55.56, Average Score: -69.19
# Process 3, Episode 540, Total Reward: -123.50, Average Score: -68.09
# Process 7, Episode 500, Total Reward: -64.58, Average Score: -71.74
# Process 1, Episode 520, Total Reward: -42.67, Average Score: -72.14
# Process 6, Episode 540, Total Reward: -52.35, Average Score: -71.84
# Process 0, Episode 530, Total Reward: 5.23, Average Score: -66.16
# Process 2, Episode 530, Total Reward: -96.64, Average Score: -65.12
# Process 4, Episode 530, Total Reward: -44.95, Average Score: -73.04
# Process 3, Episode 550, Total Reward: -53.57, Average Score: -67.74
# Process 1, Episode 530, Total Reward: -106.76, Average Score: -74.31
# Process 6, Episode 550, Total Reward: -62.31, Average Score: -71.53
# Process 7, Episode 510, Total Reward: -50.02, Average Score: -70.93
# Process 5, Episode 520, Total Reward: 1.68, Average Score: -64.76
# Process 0, Episode 540, Total Reward: -50.61, Average Score: -65.30
# Process 3, Episode 560, Total Reward: -104.04, Average Score: -67.93
# Process 7, Episode 520, Total Reward: -14.84, Average Score: -71.28
# Process 4, Episode 540, Total Reward: -16.95, Average Score: -72.99
# Process 5, Episode 530, Total Reward: -14.18, Average Score: -64.61
# Process 2, Episode 540, Total Reward: -90.79, Average Score: -66.65
# Process 0, Episode 550, Total Reward: -38.29, Average Score: -63.53
# Process 1, Episode 540, Total Reward: -26.31, Average Score: -72.53
# Process 3, Episode 570, Total Reward: -96.46, Average Score: -70.73
# Process 6, Episode 560, Total Reward: -231.05, Average Score: -73.55
# Process 7, Episode 530, Total Reward: -100.22, Average Score: -71.64
# Process 2, Episode 550, Total Reward: -36.37, Average Score: -68.95
# Process 4, Episode 550, Total Reward: -171.60, Average Score: -75.02
# Process 0, Episode 560, Total Reward: -16.22, Average Score: -65.32
# Process 5, Episode 540, Total Reward: -130.37, Average Score: -64.89
# Process 1, Episode 550, Total Reward: -109.68, Average Score: -72.99
# Process 7, Episode 540, Total Reward: -121.69, Average Score: -70.50
# Process 3, Episode 580, Total Reward: -137.42, Average Score: -73.69
# Process 6, Episode 570, Total Reward: -74.15, Average Score: -75.58
# Process 4, Episode 560, Total Reward: -66.42, Average Score: -78.81
# Process 2, Episode 560, Total Reward: 5.83, Average Score: -70.58
# Process 3, Episode 590, Total Reward: -152.79, Average Score: -73.81
# Process 0, Episode 570, Total Reward: 19.06, Average Score: -67.97
# Process 5, Episode 550, Total Reward: -51.86, Average Score: -63.77
# Process 7, Episode 550, Total Reward: -44.97, Average Score: -71.16
# Process 6, Episode 580, Total Reward: -61.16, Average Score: -75.84
# Process 1, Episode 560, Total Reward: 23.16, Average Score: -72.10
# Process 2, Episode 570, Total Reward: -71.17, Average Score: -74.86
# Process 4, Episode 570, Total Reward: -222.51, Average Score: -75.85
# Process 5, Episode 560, Total Reward: -120.24, Average Score: -64.73
# Process 6, Episode 590, Total Reward: -92.97, Average Score: -73.00
# Process 1, Episode 570, Total Reward: -53.52, Average Score: -73.75
# Process 0, Episode 580, Total Reward: -121.32, Average Score: -66.89
# Process 7, Episode 560, Total Reward: -55.12, Average Score: -70.13
# Process 3, Episode 600, Total Reward: -26.48, Average Score: -76.03
# Process 2, Episode 580, Total Reward: 13.02, Average Score: -73.84
# Process 4, Episode 580, Total Reward: -51.89, Average Score: -75.39
# Process 1, Episode 580, Total Reward: -64.36, Average Score: -71.77
# Process 3, Episode 610, Total Reward: -23.33, Average Score: -68.19
# Process 6, Episode 600, Total Reward: -81.52, Average Score: -70.17
# Process 5, Episode 570, Total Reward: -184.08, Average Score: -62.35
# Process 7, Episode 570, Total Reward: -10.66, Average Score: -70.71
# Process 0, Episode 590, Total Reward: -45.75, Average Score: -69.43
# Process 4, Episode 590, Total Reward: -125.20, Average Score: -76.79
# Process 6, Episode 610, Total Reward: -21.52, Average Score: -69.03
# Process 1, Episode 590, Total Reward: 2.25, Average Score: -72.76
# Process 3, Episode 620, Total Reward: -70.94, Average Score: -68.03
# Process 2, Episode 590, Total Reward: 2.46, Average Score: -72.71
# Process 0, Episode 600, Total Reward: -90.28, Average Score: -70.27
# Process 5, Episode 580, Total Reward: -58.06, Average Score: -63.84
# Process 6, Episode 620, Total Reward: -5.01, Average Score: -65.00
# Process 1, Episode 600, Total Reward: -57.62, Average Score: -71.69
# Process 7, Episode 580, Total Reward: -48.73, Average Score: -67.71
# Process 4, Episode 600, Total Reward: -96.43, Average Score: -74.51
# Process 2, Episode 600, Total Reward: -107.77, Average Score: -73.97
# Process 0, Episode 610, Total Reward: -29.59, Average Score: -76.67
# Process 5, Episode 590, Total Reward: -18.24, Average Score: -64.49
# Process 7, Episode 590, Total Reward: -49.68, Average Score: -67.69
# Process 3, Episode 630, Total Reward: -34.83, Average Score: -65.16
# Process 6, Episode 630, Total Reward: -14.93, Average Score: -64.16
# Process 1, Episode 610, Total Reward: -19.39, Average Score: -62.94
# Process 0, Episode 620, Total Reward: -52.23, Average Score: -75.75
# Process 4, Episode 610, Total Reward: -36.26, Average Score: -73.87
# Process 2, Episode 610, Total Reward: -36.75, Average Score: -73.57
# Process 5, Episode 600, Total Reward: -67.03, Average Score: -61.73
# Process 3, Episode 640, Total Reward: 14.54, Average Score: -65.42
# Process 7, Episode 600, Total Reward: 6.68, Average Score: -63.19
# Process 6, Episode 640, Total Reward: -22.63, Average Score: -56.41
# Process 2, Episode 620, Total Reward: 13.70, Average Score: -77.80
# Process 4, Episode 620, Total Reward: -24.70, Average Score: -73.40
# Process 5, Episode 610, Total Reward: -45.09, Average Score: -59.87
# Process 0, Episode 630, Total Reward: -91.70, Average Score: -75.04
# Process 1, Episode 620, Total Reward: -174.37, Average Score: -62.06
# Process 3, Episode 650, Total Reward: -222.11, Average Score: -66.60
# Process 5, Episode 620, Total Reward: -27.34, Average Score: -64.58
# Process 2, Episode 630, Total Reward: -55.10, Average Score: -74.83
# Process 4, Episode 630, Total Reward: -310.01, Average Score: -71.03
# Process 1, Episode 630, Total Reward: 7.47, Average Score: -63.16
# Process 7, Episode 610, Total Reward: 28.89, Average Score: -60.16
# Process 6, Episode 650, Total Reward: -67.65, Average Score: -56.60
# Process 5, Episode 630, Total Reward: 11.24, Average Score: -68.16
# Process 3, Episode 660, Total Reward: -38.24, Average Score: -64.57
# Process 0, Episode 640, Total Reward: -97.84, Average Score: -81.78
# Process 2, Episode 640, Total Reward: 6.76, Average Score: -67.14
# Process 1, Episode 640, Total Reward: 45.02, Average Score: -60.15
# Process 4, Episode 640, Total Reward: -46.08, Average Score: -67.43
# Process 6, Episode 660, Total Reward: 22.03, Average Score: -53.01
# Process 7, Episode 620, Total Reward: 9.99, Average Score: -52.10
# Process 2, Episode 650, Total Reward: -85.13, Average Score: -63.55
# Process 0, Episode 650, Total Reward: -22.64, Average Score: -80.16
# Process 5, Episode 640, Total Reward: -206.55, Average Score: -69.77
# Process 6, Episode 670, Total Reward: -32.33, Average Score: -47.56
# Process 1, Episode 650, Total Reward: 1.22, Average Score: -59.91
# Process 2, Episode 660, Total Reward: 60.61, Average Score: -59.57
# Process 4, Episode 650, Total Reward: -12.03, Average Score: -61.25
# Process 3, Episode 670, Total Reward: -25.51, Average Score: -59.39
# Process 7, Episode 630, Total Reward: -47.50, Average Score: -47.56
# Process 5, Episode 650, Total Reward: 17.54, Average Score: -66.58
# Process 4, Episode 660, Total Reward: -51.25, Average Score: -54.20
# Process 0, Episode 660, Total Reward: -31.28, Average Score: -78.56
# Process 3, Episode 680, Total Reward: -45.86, Average Score: -53.26
# Process 7, Episode 640, Total Reward: -149.06, Average Score: -46.00
# Process 1, Episode 660, Total Reward: -82.70, Average Score: -57.75
# Process 2, Episode 670, Total Reward: -3.49, Average Score: -52.27
# Process 6, Episode 680, Total Reward: -73.37, Average Score: -43.11
# Process 4, Episode 670, Total Reward: -149.06, Average Score: -50.42
# Process 1, Episode 670, Total Reward: -20.27, Average Score: -53.11
# Process 0, Episode 670, Total Reward: 25.54, Average Score: -75.72
# Process 7, Episode 650, Total Reward: -14.27, Average Score: -45.14
# Process 6, Episode 690, Total Reward: -30.55, Average Score: -39.41
# Process 5, Episode 660, Total Reward: -108.24, Average Score: -58.52
# Process 2, Episode 680, Total Reward: -9.18, Average Score: -50.79
# Process 3, Episode 690, Total Reward: -25.50, Average Score: -45.94
# Process 4, Episode 680, Total Reward: -80.42, Average Score: -46.97
# Process 7, Episode 660, Total Reward: -16.75, Average Score: -38.39
# Process 5, Episode 670, Total Reward: -24.71, Average Score: -53.06
# Process 1, Episode 680, Total Reward: -26.39, Average Score: -54.03
# Process 3, Episode 700, Total Reward: 61.45, Average Score: -42.29
# Process 2, Episode 690, Total Reward: -29.97, Average Score: -45.72
# Process 0, Episode 680, Total Reward: 85.42, Average Score: -67.75
# Process 5, Episode 680, Total Reward: -70.61, Average Score: -50.28
# Process 4, Episode 690, Total Reward: -56.58, Average Score: -40.93
# Process 7, Episode 670, Total Reward: -15.94, Average Score: -31.90
# Process 6, Episode 700, Total Reward: 5.32, Average Score: -34.90
# Process 5, Episode 690, Total Reward: -161.84, Average Score: -46.36
# Process 1, Episode 690, Total Reward: 21.69, Average Score: -50.38
# Process 0, Episode 690, Total Reward: -29.51, Average Score: -65.34
# Process 3, Episode 710, Total Reward: -54.12, Average Score: -43.22
# Process 2, Episode 700, Total Reward: -80.19, Average Score: -43.21
# Process 7, Episode 680, Total Reward: -76.30, Average Score: -29.88
# Process 4, Episode 700, Total Reward: -36.34, Average Score: -37.25
# Process 6, Episode 710, Total Reward: 66.82, Average Score: -34.69
# Process 1, Episode 700, Total Reward: -149.19, Average Score: -49.33
# Process 3, Episode 720, Total Reward: -84.21, Average Score: -40.74
# Process 5, Episode 700, Total Reward: 107.00, Average Score: -42.75
# Process 7, Episode 690, Total Reward: -106.87, Average Score: -24.05
# Process 6, Episode 720, Total Reward: -23.91, Average Score: -32.23
# Process 4, Episode 710, Total Reward: 26.80, Average Score: -31.81
# Process 2, Episode 710, Total Reward: -60.08, Average Score: -35.75
# Process 0, Episode 700, Total Reward: -48.32, Average Score: -56.75
# Process 7, Episode 700, Total Reward: 157.98, Average Score: -22.48
# Process 1, Episode 710, Total Reward: -45.82, Average Score: -46.70
# Process 5, Episode 710, Total Reward: -42.29, Average Score: -39.87
# Process 0, Episode 710, Total Reward: -6.78, Average Score: -46.26
# Process 3, Episode 730, Total Reward: 1.90, Average Score: -34.90
# Process 2, Episode 720, Total Reward: 1.21, Average Score: -26.12
# Process 0, Episode 720, Total Reward: -19.93, Average Score: -43.92
# Process 1, Episode 720, Total Reward: 62.26, Average Score: -40.77
# Process 6, Episode 730, Total Reward: -23.45, Average Score: -30.64
# Process 7, Episode 710, Total Reward: 16.27, Average Score: -17.20
# Process 4, Episode 720, Total Reward: 140.02, Average Score: -24.37
# Process 2, Episode 730, Total Reward: -40.08, Average Score: -22.36
# Process 5, Episode 720, Total Reward: 138.91, Average Score: -32.07
# Process 4, Episode 730, Total Reward: -55.27, Average Score: -23.53
# Process 7, Episode 720, Total Reward: -42.95, Average Score: -20.44
# Process 5, Episode 730, Total Reward: -31.59, Average Score: -26.44
# Process 0, Episode 730, Total Reward: 2.70, Average Score: -39.03
# Process 3, Episode 740, Total Reward: 29.38, Average Score: -26.96
# Process 1, Episode 730, Total Reward: 140.89, Average Score: -30.33
# Process 6, Episode 740, Total Reward: -45.26, Average Score: -25.86
# Process 2, Episode 740, Total Reward: -17.69, Average Score: -21.11
# Process 4, Episode 740, Total Reward: -163.40, Average Score: -22.94
# Process 7, Episode 730, Total Reward: 13.51, Average Score: -16.79
# Process 1, Episode 740, Total Reward: -89.04, Average Score: -30.39
# Process 0, Episode 740, Total Reward: -8.75, Average Score: -24.70
# Process 5, Episode 740, Total Reward: 104.37, Average Score: -20.17
# Process 2, Episode 750, Total Reward: 54.95, Average Score: -16.62
# Process 3, Episode 750, Total Reward: -2.33, Average Score: -21.95
# Process 6, Episode 750, Total Reward: 122.56, Average Score: -17.75
# Process 0, Episode 750, Total Reward: 19.15, Average Score: -20.72
# Process 1, Episode 750, Total Reward: 95.95, Average Score: -25.09
# Process 5, Episode 750, Total Reward: -10.15, Average Score: -16.44
# Process 4, Episode 750, Total Reward: 41.43, Average Score: -15.91
# Process 7, Episode 740, Total Reward: -20.91, Average Score: -12.91
# Process 2, Episode 760, Total Reward: 112.06, Average Score: -11.91
# Process 3, Episode 760, Total Reward: 72.63, Average Score: -19.76
# Process 1, Episode 760, Total Reward: -187.93, Average Score: -29.20
# Process 6, Episode 760, Total Reward: -105.91, Average Score: -12.32
# Process 3, Episode 770, Total Reward: -31.86, Average Score: -19.60
# Process 1, Episode 770, Total Reward: -20.25, Average Score: -28.42
# Process 0, Episode 760, Total Reward: -82.69, Average Score: -13.92
# Process 2, Episode 770, Total Reward: -90.59, Average Score: -9.20
# Process 7, Episode 750, Total Reward: 44.60, Average Score: -5.00
# Process 4, Episode 760, Total Reward: -151.17, Average Score: -12.07
# Process 3, Episode 780, Total Reward: 47.66, Average Score: -17.38
# Process 5, Episode 760, Total Reward: 1.77, Average Score: -13.50
# Process 1, Episode 780, Total Reward: 58.96, Average Score: -25.07
# Process 0, Episode 770, Total Reward: -48.52, Average Score: -10.83
# Process 7, Episode 760, Total Reward: 120.01, Average Score: -6.55
# Process 6, Episode 770, Total Reward: 84.98, Average Score: -8.23
# Process 2, Episode 780, Total Reward: -44.63, Average Score: -5.81
# Process 6, Episode 780, Total Reward: -19.58, Average Score: -8.39
# Process 3, Episode 790, Total Reward: -90.11, Average Score: -18.93
# Process 5, Episode 770, Total Reward: -40.39, Average Score: -16.51
# Process 1, Episode 790, Total Reward: -21.99, Average Score: -23.17
# Process 4, Episode 770, Total Reward: -151.45, Average Score: -10.82
# Process 7, Episode 770, Total Reward: -218.75, Average Score: -8.88
# Process 0, Episode 780, Total Reward: -180.85, Average Score: -14.26
# Process 2, Episode 790, Total Reward: -121.78, Average Score: -8.60
# Process 7, Episode 780, Total Reward: 18.41, Average Score: -7.41
# Process 3, Episode 800, Total Reward: 28.64, Average Score: -13.33
# Process 5, Episode 780, Total Reward: 18.92, Average Score: -12.90
# Process 1, Episode 800, Total Reward: -40.05, Average Score: -16.72
# Process 0, Episode 790, Total Reward: -20.73, Average Score: -8.95
# Process 6, Episode 790, Total Reward: 100.75, Average Score: -5.02
# Process 7, Episode 790, Total Reward: -59.71, Average Score: -7.87
# Process 4, Episode 780, Total Reward: 83.89, Average Score: -5.00
# Process 5, Episode 790, Total Reward: 19.91, Average Score: -7.09
# Process 2, Episode 800, Total Reward: 118.17, Average Score: -1.05
# Process 3, Episode 810, Total Reward: -176.59, Average Score: -12.34
# Process 0, Episode 800, Total Reward: -50.96, Average Score: -11.46
# Process 6, Episode 800, Total Reward: -155.98, Average Score: -9.15
# Process 7, Episode 800, Total Reward: 87.15, Average Score: -7.82
# Process 1, Episode 810, Total Reward: 74.32, Average Score: -12.21
# Process 5, Episode 800, Total Reward: -16.97, Average Score: -10.81
# Process 4, Episode 790, Total Reward: 85.65, Average Score: -2.99
# Process 7, Episode 810, Total Reward: -30.13, Average Score: -11.94
# Process 0, Episode 810, Total Reward: 59.32, Average Score: -11.92
# Process 1, Episode 820, Total Reward: -37.40, Average Score: -12.16
# Process 3, Episode 820, Total Reward: 0.27, Average Score: -6.12
# Process 6, Episode 810, Total Reward: 0.57, Average Score: -5.78
# Process 5, Episode 810, Total Reward: 113.49, Average Score: -9.81
# Process 2, Episode 810, Total Reward: 103.88, Average Score: 4.17
# Process 4, Episode 800, Total Reward: -60.17, Average Score: -4.57
# Process 7, Episode 820, Total Reward: -68.68, Average Score: -11.59
# Process 0, Episode 820, Total Reward: 98.26, Average Score: -6.20
# Process 1, Episode 830, Total Reward: 111.65, Average Score: -16.18
# Process 3, Episode 830, Total Reward: -185.80, Average Score: -8.55
# Process 4, Episode 810, Total Reward: -62.70, Average Score: -7.74
# Process 6, Episode 820, Total Reward: 141.22, Average Score: -1.90
# Process 5, Episode 820, Total Reward: 3.08, Average Score: -9.60
# Process 7, Episode 830, Total Reward: 8.18, Average Score: -12.50
# Process 2, Episode 820, Total Reward: -164.40, Average Score: 6.46
# Process 0, Episode 830, Total Reward: -23.35, Average Score: -5.56
# Process 1, Episode 840, Total Reward: -61.41, Average Score: -16.62
# Process 6, Episode 830, Total Reward: -27.40, Average Score: -1.51
# Process 4, Episode 820, Total Reward: 2.83, Average Score: -10.44
# Process 3, Episode 840, Total Reward: -32.95, Average Score: -11.46
# Process 5, Episode 830, Total Reward: 23.58, Average Score: -8.80
# Process 7, Episode 840, Total Reward: 16.43, Average Score: -11.05
# Process 6, Episode 840, Total Reward: -124.47, Average Score: -4.33
# Process 1, Episode 850, Total Reward: 11.82, Average Score: -15.15
# Process 4, Episode 830, Total Reward: 30.55, Average Score: -6.14
# Process 2, Episode 830, Total Reward: 56.00, Average Score: 10.81
# Process 3, Episode 850, Total Reward: 160.20, Average Score: -7.36
# Process 0, Episode 840, Total Reward: 114.20, Average Score: -3.84
# Process 5, Episode 840, Total Reward: -48.37, Average Score: -5.43
# Process 6, Episode 850, Total Reward: -67.68, Average Score: -9.34
# Process 4, Episode 840, Total Reward: -37.12, Average Score: -8.89
# Process 7, Episode 850, Total Reward: 29.89, Average Score: -10.78
# Process 6, Episode 860, Total Reward: 70.11, Average Score: -13.18
# Process 1, Episode 860, Total Reward: 125.00, Average Score: -4.44
# Process 2, Episode 840, Total Reward: 131.46, Average Score: 12.97
# Process 0, Episode 850, Total Reward: 40.38, Average Score: -5.33
# Process 3, Episode 860, Total Reward: 35.42, Average Score: -2.89
# Process 7, Episode 860, Total Reward: -150.98, Average Score: -10.33
# Process 4, Episode 850, Total Reward: 53.08, Average Score: -12.04
# Process 3, Episode 870, Total Reward: 31.03, Average Score: -3.24
# Process 1, Episode 870, Total Reward: -8.31, Average Score: -3.16
# Process 5, Episode 850, Total Reward: 55.70, Average Score: -4.34
# Process 2, Episode 850, Total Reward: 124.82, Average Score: 14.63
# Process 0, Episode 860, Total Reward: -67.22, Average Score: -3.92
# Process 6, Episode 870, Total Reward: 35.50, Average Score: -11.05
# Process 4, Episode 860, Total Reward: -30.01, Average Score: -12.92
# Process 3, Episode 880, Total Reward: -14.28, Average Score: -3.45
# Process 7, Episode 870, Total Reward: 27.70, Average Score: -3.59
# Process 2, Episode 860, Total Reward: 69.48, Average Score: 12.91
# Process 1, Episode 880, Total Reward: 105.09, Average Score: 2.37
# Process 4, Episode 870, Total Reward: 90.41, Average Score: -12.81
# Process 5, Episode 860, Total Reward: 74.82, Average Score: -3.89
# Process 0, Episode 870, Total Reward: 70.21, Average Score: 2.44
# Process 6, Episode 880, Total Reward: 91.25, Average Score: -5.79
# Process 3, Episode 890, Total Reward: -68.96, Average Score: -0.54
# Process 7, Episode 880, Total Reward: -70.65, Average Score: 0.85
# Process 5, Episode 870, Total Reward: -70.19, Average Score: -3.92
# ...
# Process 6, Episode 1520, Total Reward: 152.43, Average Score: 118.24
# Process 2, Episode 1500, Total Reward: 199.39, Average Score: 109.97
# Process 0, Episode 1520, Total Reward: -14.83, Average Score: 102.12
# Process 1, Episode 1510, Total Reward: 256.84, Average Score: 138.93
# Process 5, Episode 1510, Total Reward: 81.84, Average Score: 127.00
# Process 3, Episode 1510, Total Reward: -38.92, Average Score: 119.54
# Process 4, Episode 1510, Total Reward: -6.32, Average Score: 117.17
# Process 6, Episode 1530, Total Reward: -138.00, Average Score: 115.06
# Process 7, Episode 1510, Total Reward: 74.91, Average Score: 110.18
# Process 2, Episode 1510, Total Reward: 86.06, Average Score: 112.36
# Process 1, Episode 1520, Total Reward: 201.94, Average Score: 134.05
# Process 0, Episode 1530, Total Reward: 14.07, Average Score: 103.26
# Process 5, Episode 1520, Total Reward: 211.06, Average Score: 129.04
# Process 3, Episode 1520, Total Reward: 244.64, Average Score: 122.30
# Process 6, Episode 1540, Total Reward: 110.37, Average Score: 116.96
# Process 4, Episode 1520, Total Reward: 123.69, Average Score: 116.68
# Process 2, Episode 1520, Total Reward: 110.00, Average Score: 111.32
# Process 7, Episode 1520, Total Reward: 107.64, Average Score: 114.26
# Process 1, Episode 1530, Total Reward: -240.17, Average Score: 127.83
# Process 0, Episode 1540, Total Reward: 208.64, Average Score: 103.30
# Process 3, Episode 1530, Total Reward: 221.36, Average Score: 128.79
# Process 4, Episode 1530, Total Reward: 236.92, Average Score: 113.25
# Process 5, Episode 1530, Total Reward: -105.89, Average Score: 127.46
# Process 2, Episode 1530, Total Reward: -1.80, Average Score: 104.97
# Process 6, Episode 1550, Total Reward: 108.50, Average Score: 118.67
# Process 1, Episode 1540, Total Reward: -1.60, Average Score: 121.72
# Process 7, Episode 1530, Total Reward: 107.97, Average Score: 115.57
# Process 2, Episode 1540, Total Reward: -32.61, Average Score: 98.18
# Process 3, Episode 1540, Total Reward: -35.51, Average Score: 133.07
# Process 0, Episode 1550, Total Reward: 274.90, Average Score: 109.13
# Process 4, Episode 1540, Total Reward: 242.43, Average Score: 110.26
# Process 5, Episode 1540, Total Reward: 28.23, Average Score: 132.33
# Process 6, Episode 1560, Total Reward: 257.68, Average Score: 120.20
# Process 7, Episode 1540, Total Reward: -126.06, Average Score: 116.63
# Process 2, Episode 1550, Total Reward: 135.98, Average Score: 89.84
# Process 1, Episode 1550, Total Reward: 271.87, Average Score: 121.93
# Process 5, Episode 1550, Total Reward: 10.47, Average Score: 133.51
# Process 0, Episode 1560, Total Reward: 137.85, Average Score: 108.73
# Process 4, Episode 1550, Total Reward: 16.23, Average Score: 117.41
# Process 3, Episode 1550, Total Reward: 142.63, Average Score: 126.76
# Process 6, Episode 1570, Total Reward: 14.58, Average Score: 119.09
# Process 7, Episode 1550, Total Reward: 257.79, Average Score: 120.59
# Process 2, Episode 1560, Total Reward: 205.99, Average Score: 100.90
# Process 6, Episode 1580, Total Reward: 47.03, Average Score: 129.51
# Process 3, Episode 1560, Total Reward: 273.49, Average Score: 127.04
# Process 5, Episode 1560, Total Reward: 261.64, Average Score: 139.77
# Process 0, Episode 1570, Total Reward: 6.99, Average Score: 107.57
# Process 1, Episode 1560, Total Reward: 178.91, Average Score: 128.00
# Process 4, Episode 1560, Total Reward: 4.33, Average Score: 120.40
# Process 7, Episode 1560, Total Reward: 197.39, Average Score: 118.05
# Process 2, Episode 1570, Total Reward: 84.07, Average Score: 109.09
# Process 5, Episode 1570, Total Reward: 213.92, Average Score: 138.04
# Process 1, Episode 1570, Total Reward: 279.11, Average Score: 131.60
# Process 3, Episode 1570, Total Reward: 267.45, Average Score: 140.07
# Process 6, Episode 1590, Total Reward: 101.70, Average Score: 138.38
# Process 0, Episode 1580, Total Reward: 160.49, Average Score: 118.17
# Process 7, Episode 1570, Total Reward: 238.06, Average Score: 121.96
# Process 4, Episode 1570, Total Reward: 236.27, Average Score: 129.24
# Process 6, Episode 1600, Total Reward: 216.05, Average Score: 131.01
# Process 2, Episode 1580, Total Reward: 116.06, Average Score: 113.28
# Process 3, Episode 1580, Total Reward: 268.97, Average Score: 149.25
# Process 5, Episode 1580, Total Reward: -134.87, Average Score: 136.66
# Process 1, Episode 1580, Total Reward: 81.83, Average Score: 130.91
# Process 0, Episode 1590, Total Reward: 130.96, Average Score: 132.08
# Process 7, Episode 1580, Total Reward: 263.37, Average Score: 137.90
# Process 4, Episode 1580, Total Reward: 261.30, Average Score: 134.40
# Process 2, Episode 1590, Total Reward: -32.59, Average Score: 114.97
# Process 6, Episode 1610, Total Reward: 3.74, Average Score: 131.86
# Process 5, Episode 1590, Total Reward: 216.13, Average Score: 147.26
# Process 3, Episode 1590, Total Reward: 277.33, Average Score: 151.67
# Process 0, Episode 1600, Total Reward: 264.94, Average Score: 141.20
# Process 1, Episode 1590, Total Reward: 257.10, Average Score: 136.40
# Process 7, Episode 1590, Total Reward: 103.70, Average Score: 153.32
# Process 4, Episode 1590, Total Reward: 229.37, Average Score: 136.31
# Process 2, Episode 1600, Total Reward: 261.71, Average Score: 117.02
# Process 6, Episode 1620, Total Reward: 211.63, Average Score: 134.85
# Process 3, Episode 1600, Total Reward: -19.91, Average Score: 154.95
# Process 5, Episode 1600, Total Reward: -137.64, Average Score: 138.07
# Process 0, Episode 1610, Total Reward: 262.54, Average Score: 142.57
# Process 2, Episode 1610, Total Reward: -117.43, Average Score: 106.35
# Process 1, Episode 1600, Total Reward: 274.47, Average Score: 138.47
# Process 4, Episode 1600, Total Reward: 283.67, Average Score: 140.53
# Process 7, Episode 1600, Total Reward: 89.96, Average Score: 144.82
# Process 3, Episode 1610, Total Reward: 93.66, Average Score: 152.29
# Process 6, Episode 1630, Total Reward: 144.22, Average Score: 140.82
# Process 2, Episode 1620, Total Reward: 77.83, Average Score: 108.29
# Process 5, Episode 1610, Total Reward: 254.94, Average Score: 147.65
# Process 4, Episode 1610, Total Reward: 201.40, Average Score: 142.82
# Process 1, Episode 1610, Total Reward: 132.27, Average Score: 143.63
# Process 0, Episode 1620, Total Reward: 21.24, Average Score: 145.64
# Process 7, Episode 1610, Total Reward: 180.43, Average Score: 152.93
# Process 3, Episode 1620, Total Reward: 247.48, Average Score: 148.49
# Process 6, Episode 1640, Total Reward: 191.25, Average Score: 144.71
# Process 2, Episode 1630, Total Reward: -165.65, Average Score: 110.12
# Process 1, Episode 1620, Total Reward: 269.53, Average Score: 152.81
# Process 4, Episode 1620, Total Reward: 47.92, Average Score: 150.55
# Process 0, Episode 1630, Total Reward: 210.92, Average Score: 149.54
# Process 7, Episode 1620, Total Reward: 250.07, Average Score: 146.21
# Process 5, Episode 1620, Total Reward: 256.56, Average Score: 153.13
# Process 2, Episode 1640, Total Reward: -30.08, Average Score: 120.23
# Process 6, Episode 1650, Total Reward: 52.23, Average Score: 148.83
# Process 4, Episode 1630, Total Reward: 262.67, Average Score: 154.37
# Process 3, Episode 1630, Total Reward: 121.18, Average Score: 147.57
# Process 1, Episode 1630, Total Reward: -4.09, Average Score: 161.00
# Process 0, Episode 1640, Total Reward: 205.20, Average Score: 151.81
# Process 5, Episode 1630, Total Reward: 179.14, Average Score: 156.52
# Process 7, Episode 1630, Total Reward: 124.81, Average Score: 143.93
# Process 2, Episode 1650, Total Reward: 256.05, Average Score: 124.79
# Process 4, Episode 1640, Total Reward: 185.26, Average Score: 157.67
# Process 3, Episode 1640, Total Reward: 19.51, Average Score: 149.01
# Process 1, Episode 1640, Total Reward: 228.23, Average Score: 169.73
# Process 6, Episode 1660, Total Reward: 121.86, Average Score: 147.72
# Process 0, Episode 1650, Total Reward: 251.89, Average Score: 147.29
# Process 5, Episode 1640, Total Reward: 16.59, Average Score: 156.92
# Process 4, Episode 1650, Total Reward: 15.20, Average Score: 150.58
# Process 6, Episode 1670, Total Reward: 196.98, Average Score: 147.94
# Process 2, Episode 1660, Total Reward: 257.26, Average Score: 125.82
# Process 7, Episode 1640, Total Reward: 121.45, Average Score: 148.98
# Process 3, Episode 1650, Total Reward: 93.56, Average Score: 153.55
# Process 0, Episode 1660, Total Reward: 28.89, Average Score: 145.15
# Process 1, Episode 1650, Total Reward: 32.06, Average Score: 164.20
# Process 5, Episode 1650, Total Reward: 185.83, Average Score: 158.91
# Process 6, Episode 1680, Total Reward: 32.20, Average Score: 143.07
# Process 4, Episode 1660, Total Reward: 17.05, Average Score: 148.20
# Process 2, Episode 1670, Total Reward: 220.39, Average Score: 129.02
# Process 1, Episode 1660, Total Reward: 192.55, Average Score: 167.59
# Process 0, Episode 1670, Total Reward: 231.11, Average Score: 146.76
# Process 3, Episode 1660, Total Reward: -49.80, Average Score: 160.81
# Process 5, Episode 1660, Total Reward: 241.24, Average Score: 156.78
# Process 7, Episode 1650, Total Reward: 51.29, Average Score: 151.04
# Process 6, Episode 1690, Total Reward: 258.10, Average Score: 141.79
# Process 3, Episode 1670, Total Reward: 19.41, Average Score: 156.20
# Process 4, Episode 1670, Total Reward: 26.36, Average Score: 144.64
# Process 2, Episode 1680, Total Reward: 258.16, Average Score: 133.59
# Process 0, Episode 1680, Total Reward: 136.52, Average Score: 144.71
# Process 6, Episode 1700, Total Reward: 239.74, Average Score: 147.61
# Process 1, Episode 1670, Total Reward: 97.85, Average Score: 169.05
# Process 5, Episode 1670, Total Reward: 79.40, Average Score: 160.08
# Process 3, Episode 1680, Total Reward: 178.58, Average Score: 149.06
# Process 4, Episode 1680, Total Reward: 27.94, Average Score: 133.73
# Process 7, Episode 1660, Total Reward: 244.29, Average Score: 158.02
# Process 2, Episode 1690, Total Reward: 246.11, Average Score: 138.66
# Process 6, Episode 1710, Total Reward: 127.55, Average Score: 150.34
# Process 5, Episode 1680, Total Reward: 24.50, Average Score: 160.78
# Process 1, Episode 1680, Total Reward: 299.11, Average Score: 174.77
# Process 0, Episode 1690, Total Reward: 262.67, Average Score: 139.93
# Process 3, Episode 1690, Total Reward: 114.00, Average Score: 152.91
# Process 5, Episode 1690, Total Reward: 234.42, Average Score: 163.10
# Process 2, Episode 1700, Total Reward: 259.15, Average Score: 138.11
# Process 6, Episode 1720, Total Reward: 52.79, Average Score: 149.01
# Process 1, Episode 1690, Total Reward: 267.35, Average Score: 170.77
# Process 0, Episode 1700, Total Reward: 241.96, Average Score: 143.90
# Process 4, Episode 1690, Total Reward: 119.69, Average Score: 135.95
# Process 7, Episode 1670, Total Reward: 237.76, Average Score: 157.86
# Process 3, Episode 1700, Total Reward: 129.59, Average Score: 157.99
# Process 2, Episode 1710, Total Reward: 259.86, Average Score: 153.57
# Process 5, Episode 1700, Total Reward: 132.97, Average Score: 172.37
# Process 1, Episode 1700, Total Reward: 278.44, Average Score: 176.42
# Process 6, Episode 1730, Total Reward: 255.56, Average Score: 156.27
# Process 0, Episode 1710, Total Reward: 156.07, Average Score: 151.83
# Process 4, Episode 1700, Total Reward: 7.51, Average Score: 132.79
# Process 5, Episode 1710, Total Reward: 271.36, Average Score: 169.44
# Process 2, Episode 1720, Total Reward: 241.67, Average Score: 165.37
# Process 7, Episode 1680, Total Reward: 229.94, Average Score: 160.00
# Process 1, Episode 1710, Total Reward: 251.73, Average Score: 179.56
# Process 6, Episode 1740, Total Reward: 262.21, Average Score: 161.87
# Process 3, Episode 1710, Total Reward: 26.06, Average Score: 166.59
# Process 4, Episode 1710, Total Reward: 229.41, Average Score: 139.07
# Process 0, Episode 1720, Total Reward: 262.50, Average Score: 157.01
# Process 2, Episode 1730, Total Reward: 18.47, Average Score: 178.85
# Process 6, Episode 1750, Total Reward: 255.65, Average Score: 168.29
# Process 1, Episode 1720, Total Reward: 293.16, Average Score: 180.25
# Process 4, Episode 1720, Total Reward: 290.76, Average Score: 143.70
# Process 5, Episode 1720, Total Reward: 165.22, Average Score: 171.99
# Process 0, Episode 1730, Total Reward: 35.82, Average Score: 168.64
# Process 3, Episode 1720, Total Reward: 4.29, Average Score: 174.81
# Process 2, Episode 1740, Total Reward: 212.78, Average Score: 181.46
# Process 7, Episode 1690, Total Reward: 112.36, Average Score: 156.65
# Process 4, Episode 1730, Total Reward: 216.82, Average Score: 138.35
# Process 2, Episode 1750, Total Reward: 27.36, Average Score: 181.14
# Process 5, Episode 1730, Total Reward: 261.72, Average Score: 173.86
# Process 6, Episode 1760, Total Reward: 263.65, Average Score: 170.91
# Process 1, Episode 1730, Total Reward: 274.53, Average Score: 184.35
# Process 0, Episode 1740, Total Reward: 279.15, Average Score: 169.44
# Process 4, Episode 1740, Total Reward: -31.75, Average Score: 144.26
# Process 3, Episode 1730, Total Reward: 224.28, Average Score: 176.91
# Process 7, Episode 1700, Total Reward: 229.92, Average Score: 164.65
# Process 5, Episode 1740, Total Reward: 258.53, Average Score: 180.12
# Process 1, Episode 1740, Total Reward: 23.66, Average Score: 189.90
# Process 6, Episode 1770, Total Reward: 253.97, Average Score: 174.82
# Process 2, Episode 1760, Total Reward: 262.22, Average Score: 182.10
# Process 0, Episode 1750, Total Reward: 224.78, Average Score: 178.84
# Process 3, Episode 1740, Total Reward: 245.43, Average Score: 184.13
# Process 4, Episode 1750, Total Reward: 238.50, Average Score: 157.10
# Process 1, Episode 1750, Total Reward: -24.77, Average Score: 188.24
# Process 7, Episode 1710, Total Reward: -33.60, Average Score: 157.91
# Process 6, Episode 1780, Total Reward: 234.51, Average Score: 180.78
# Process 5, Episode 1750, Total Reward: 102.66, Average Score: 186.53
# Process 2, Episode 1770, Total Reward: 227.99, Average Score: 182.28
# Process 1, Episode 1760, Total Reward: 242.08, Average Score: 185.35
# Process 6, Episode 1790, Total Reward: 285.26, Average Score: 189.79
# Process 4, Episode 1760, Total Reward: 276.53, Average Score: 170.03
# Process 0, Episode 1760, Total Reward: 146.50, Average Score: 177.16
# Process 7, Episode 1720, Total Reward: 245.65, Average Score: 175.04
# Process 2, Episode 1780, Total Reward: 5.56, Average Score: 179.69
# Process 3, Episode 1750, Total Reward: 228.34, Average Score: 189.61
# Process 5, Episode 1760, Total Reward: 201.54, Average Score: 179.67
# Process 1, Episode 1770, Total Reward: 33.40, Average Score: 189.53
# Process 3, Episode 1760, Total Reward: 237.58, Average Score: 190.93
# Process 4, Episode 1770, Total Reward: 220.04, Average Score: 177.81
# Process 6, Episode 1800, Total Reward: 243.79, Average Score: 192.31
# Process 0, Episode 1770, Total Reward: 238.89, Average Score: 176.63
# Process 2, Episode 1790, Total Reward: 100.34, Average Score: 176.35
# Process 1, Episode 1780, Total Reward: 253.26, Average Score: 187.53
# Process 7, Episode 1730, Total Reward: 266.63, Average Score: 183.20
# Process 5, Episode 1770, Total Reward: 16.74, Average Score: 178.14
# Process 4, Episode 1780, Total Reward: 299.22, Average Score: 181.80
# Process 6, Episode 1810, Total Reward: 39.46, Average Score: 192.40
# Process 3, Episode 1770, Total Reward: 256.40, Average Score: 193.50
# Process 0, Episode 1780, Total Reward: 237.32, Average Score: 180.60
# Process 7, Episode 1740, Total Reward: 169.58, Average Score: 180.30
# Process 2, Episode 1800, Total Reward: 7.25, Average Score: 178.89
# Process 5, Episode 1780, Total Reward: 216.32, Average Score: 183.52
# Process 4, Episode 1790, Total Reward: 227.92, Average Score: 189.98
# Process 1, Episode 1790, Total Reward: 234.31, Average Score: 191.19
# Process 3, Episode 1780, Total Reward: 199.85, Average Score: 197.20
# Process 6, Episode 1820, Total Reward: -29.73, Average Score: 189.67
# Process 7, Episode 1750, Total Reward: 16.75, Average Score: 178.39
# Process 0, Episode 1790, Total Reward: 244.49, Average Score: 186.39
# Process 4, Episode 1800, Total Reward: 308.12, Average Score: 197.50
# Process 1, Episode 1800, Total Reward: 256.28, Average Score: 192.78
# Process 5, Episode 1790, Total Reward: 267.57, Average Score: 186.13
# Total Training Time: 4.54

# %%
env = gym.make('LunarLander-v3', render_mode="rgb_array")

state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# init agent
Q = QNetwork(state_size, action_size, hidden_size=128).to(device)

agent = Agent(
    state_size=state_size,
    action_size=action_size,
    Q_network=Q,
    gamma=0.995,
)

# load the weights from file
agent.Q.load_state_dict(torch.load('checkpoint.pth'))

env = gym.make("LunarLander-v3", render_mode="rgb_array")

avg_score = 0
for i in range(3):
	state, info = env.reset(seed=123+i)
	total_reward = 0
	for t in range(500):
		# clear frame
		display.clear_output(wait=True)

		action = agent.select_action(state)

		# render game
		frame = env.render()
		display.display(Image.fromarray(frame))
		time.sleep(0.05)

		state, reward, done, _, info = env.step(action)
		total_reward += reward
		if done:
			break
	
	avg_score += total_reward
	print('Final score:', total_reward)
env.close()
print(f"Average score: {avg_score / 3}")
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>
# Final score: 240.13742156301583
# Average score: 267.47662548649083

# %% [markdown]
# ### 8. Summary
#
#
# This implementation leverages an asynchronous parallel version of Deep Q-Learning, which eliminates the dependency on a replay buffer by using multiple processes to independently interact with the environment and update the shared Q-network. Compared to a traditional **[Dueling DDQN](../variants-dqn/dueling_ddqn_lunarlander.ipynb)** implementation, which takes approximately **22 minutes** to solve the same task, this parallel version achieves a significant speedup. Running entirely on the **CPU**, it completes training in just **4.29 minutes**, demonstrating a **5x improvement in efficiency** while maintaining competitive performance. This acceleration is particularly beneficial for environments with computational constraints or limited access to GPUs.
